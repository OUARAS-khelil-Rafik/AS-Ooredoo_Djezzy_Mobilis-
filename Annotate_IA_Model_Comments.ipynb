# %% [markdown]
# <a href="https://colab.research.google.com/github/OUARAS-khelil-Rafik/AS-Ooredoo_Djezzy_Mobilis-/blob/main/Annotate_IA_Model_Comments.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install emoji pandas
# Out:
# Collecting emoji
#   Downloading emoji-2.14.1-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading emoji-2.14.1-py3-none-any.whl (590 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 590.6/590.6 kB 26.8 MB/s eta 0:00:00
# Installing collected packages: emoji
# Successfully installed emoji-2.14.1

# %%
import pandas as pd
import re
import emoji

# %%
# Charger les fichiers Excel
comments_df = pd.read_excel('/content/Comments.xlsx')

# Afficher DataFrame "Comments"
comments_df
# Out:
#       ID Post        User Name  \
# 0           1  Samir Bekhouche
# 1           1    Yanise Yanise
# 2           1           Jj Kie
# 3           1     Sakou Younes
# 4           1       راني نعاني
# ...       ...              ...
# 4097      183       Ĺã Rõsë Ýb
# 4098      183      نسمات هادئة
# 4099      183   ملك ملهاش غيرك
# 4100      183        سعيدي رضا
# 4101      183    جيبلي فيت فيت
#
#                                                Comments Sentiments
# 0                                                   NaN     Neutre
# 1     سلام عليكم ورحمة لديا مشكلة ! فليكسيت 100 دج و...    Negatif
# 2                                    كل عام و انتم بخير    Positif
# 3                                    كل عام و أنتم بخير    Positif
# 4                                     كل عام و حنا بخير    Positif
# ...                                                 ...        ...
# 4097                                               ❤️❤️    Positif
# 4098                                               💕💕💕💕    Positif
# 4099                                            ❤❤❤❤❤❤🌹    Positif
# 4100                                                NaN     Neutre
# 4101                                           ❤️❤️❤️❤️    Positif
#
# [4102 rows x 4 columns]

# %% [markdown]
# # Pré-traitement

# %%
# Suppression des lignes où "User Name" est "Djezzy", "Mobilis" ou "Ooredoo"
comments_df = comments_df[~comments_df["User Name"].isin(["Djezzy", "Mobilis", "Ooredoo Algérie"])]
comments_df
# Out:
#       ID Post        User Name  \
# 0           1  Samir Bekhouche
# 1           1    Yanise Yanise
# 2           1           Jj Kie
# 3           1     Sakou Younes
# 4           1       راني نعاني
# ...       ...              ...
# 4097      183       Ĺã Rõsë Ýb
# 4098      183      نسمات هادئة
# 4099      183   ملك ملهاش غيرك
# 4100      183        سعيدي رضا
# 4101      183    جيبلي فيت فيت
#
#                                                Comments Sentiments
# 0                                                   NaN     Neutre
# 1     سلام عليكم ورحمة لديا مشكلة ! فليكسيت 100 دج و...    Negatif
# 2                                    كل عام و انتم بخير    Positif
# 3                                    كل عام و أنتم بخير    Positif
# 4                                     كل عام و حنا بخير    Positif
# ...                                                 ...        ...
# 4097                                               ❤️❤️    Positif
# 4098                                               💕💕💕💕    Positif
# 4099                                            ❤❤❤❤❤❤🌹    Positif
# 4100                                                NaN     Neutre
# 4101                                           ❤️❤️❤️❤️    Positif
#
# [4077 rows x 4 columns]

# %%
comments_df = comments_df.dropna(subset=["Comments"])
comments_df = comments_df[comments_df["Comments"].str.strip() != ""]
comments_df
# Out:
#       ID Post       User Name  \
# 1           1   Yanise Yanise
# 2           1          Jj Kie
# 3           1    Sakou Younes
# 4           1      راني نعاني
# 5           1     Wahab Ziadi
# ...       ...             ...
# 4096      183      مر سلين 'ے
# 4097      183      Ĺã Rõsë Ýb
# 4098      183     نسمات هادئة
# 4099      183  ملك ملهاش غيرك
# 4101      183   جيبلي فيت فيت
#
#                                                Comments Sentiments
# 1     سلام عليكم ورحمة لديا مشكلة ! فليكسيت 100 دج و...    Negatif
# 2                                    كل عام و انتم بخير    Positif
# 3                                    كل عام و أنتم بخير    Positif
# 4                                     كل عام و حنا بخير    Positif
# 5                                     كل عام و حنا بخير    Positif
# ...                                                 ...        ...
# 4096                                             🩷🩷🩷🩷🩷🩷    Positif
# 4097                                               ❤️❤️    Positif
# 4098                                               💕💕💕💕    Positif
# 4099                                            ❤❤❤❤❤❤🌹    Positif
# 4101                                           ❤️❤️❤️❤️    Positif
#
# [3897 rows x 4 columns]

# %%
comments_df = comments_df.loc[comments_df["Comments"].shift() != comments_df["Comments"]]
comments_df
# Out:
#       ID Post       User Name  \
# 1           1   Yanise Yanise
# 2           1          Jj Kie
# 3           1    Sakou Younes
# 4           1      راني نعاني
# 6           1      أحمد فيراس
# ...       ...             ...
# 4096      183      مر سلين 'ے
# 4097      183      Ĺã Rõsë Ýb
# 4098      183     نسمات هادئة
# 4099      183  ملك ملهاش غيرك
# 4101      183   جيبلي فيت فيت
#
#                                                Comments Sentiments
# 1     سلام عليكم ورحمة لديا مشكلة ! فليكسيت 100 دج و...    Negatif
# 2                                    كل عام و انتم بخير    Positif
# 3                                    كل عام و أنتم بخير    Positif
# 4                                     كل عام و حنا بخير    Positif
# 6                                                     🥰    Positif
# ...                                                 ...        ...
# 4096                                             🩷🩷🩷🩷🩷🩷    Positif
# 4097                                               ❤️❤️    Positif
# 4098                                               💕💕💕💕    Positif
# 4099                                            ❤❤❤❤❤❤🌹    Positif
# 4101                                           ❤️❤️❤️❤️    Positif
#
# [3798 rows x 4 columns]

# %%
def normalize_arabic(text):
    text = text.lower()
    text = re.sub("گ", "ك", text)
    text = re.sub("ڭ", "ك", text)
    text = re.sub("ڤ", "ق", text)
    text = re.sub("ڨ", "ق", text)
    text = re.sub("پ", "ب", text)
    text = re.sub("é", "e", text)
    text = re.sub("ê", "e", text)
    text = re.sub("ë", "e", text)
    text = re.sub("ç", "c", text)
    text = re.sub("à", "a", text)
    text = re.sub("â", "a", text)
    text = re.sub("ä", "a", text)
    text = re.sub("î", "i", text)
    text = re.sub("ï", "a", text)
    text = re.sub("æ", "ae", text)
    text = re.sub("œ", "oe", text)
    return text

# Appliquer la normalisation
comments_df["Comments"] = comments_df["Comments"].apply(normalize_arabic)

comments_df
# Out:
# <ipython-input-7-378408359fdb>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   comments_df["Comments"] = comments_df["Comments"].apply(normalize_arabic)
#       ID Post       User Name  \
# 1           1   Yanise Yanise
# 2           1          Jj Kie
# 3           1    Sakou Younes
# 4           1      راني نعاني
# 6           1      أحمد فيراس
# ...       ...             ...
# 4096      183      مر سلين 'ے
# 4097      183      Ĺã Rõsë Ýb
# 4098      183     نسمات هادئة
# 4099      183  ملك ملهاش غيرك
# 4101      183   جيبلي فيت فيت
#
#                                                Comments Sentiments
# 1     سلام عليكم ورحمة لديا مشكلة ! فليكسيت 100 دج و...    Negatif
# 2                                    كل عام و انتم بخير    Positif
# 3                                    كل عام و أنتم بخير    Positif
# 4                                     كل عام و حنا بخير    Positif
# 6                                                     🥰    Positif
# ...                                                 ...        ...
# 4096                                             🩷🩷🩷🩷🩷🩷    Positif
# 4097                                               ❤️❤️    Positif
# 4098                                               💕💕💕💕    Positif
# 4099                                            ❤❤❤❤❤❤🌹    Positif
# 4101                                           ❤️❤️❤️❤️    Positif
#
# [3798 rows x 4 columns]

# %%
def clean_text(text):
    text = emoji.replace_emoji(text, replace=" ")  # Supprimer les emojis
    text = re.sub(r'http\S+ | htps\S+', " ", str(text))  # Supprimer les hyperliens
    text = re.sub(r'((www\.[^\s]+)|(https?://[^\s]+))', " ", str(text))  # Supprimer les URL
    text = re.sub(r'@\S+', '', str(text))  # Supprimer les mots commençant par @
    text = text.replace("_", " ").replace("#", "")  # Supprimer # et _
    text = text.replace("'", " ")  # Supprimer '
    text = re.sub(r'\. | , | ، | ؛', " ", text)  # Supprimer les ponctuations

    # Supprimer les mots réservés
    text = re.sub(r'\bRT\b | \bRetweeted\b', " ", text)

    # Supprimer tout caractère spécial sauf l'alphabet arabe et latin
    text = re.sub(r'[^a-zA-Z0-9\u0600-\u06FF\s]', " ", text)

    # Supprimer les voyelles courtes arabes (حركات)
    harakat = "[\u064B-\u0652]"  # Comprend
    text = re.sub(harakat, '', text)

    text = re.sub(r"(.)\1{2,}", r"\1", text)  # Supprimer les caractères consécutifs en double
    text = text.replace('\n', " ").replace('/', " ")  # Supprimer sauts de ligne et /
    text = re.sub(r'[^\w\s]', " ", text)  # Supprimer les caractères spéciaux

    return text.strip()

comments_df["Comments"] = comments_df["Comments"].apply(clean_text)

# Remplacer les valeurs nulles par une chaîne vide
comments_df["Comments"] = comments_df["Comments"].fillna('')

comments_df = comments_df.dropna(subset=["Comments"])
comments_df = comments_df[comments_df["Comments"].str.strip() != ""]

comments_df
# Out:
# <ipython-input-8-6f9557cab524>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   comments_df["Comments"] = comments_df["Comments"].apply(clean_text)
# <ipython-input-8-6f9557cab524>:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   comments_df["Comments"] = comments_df["Comments"].fillna('')
#       ID Post                User Name  \
# 1           1            Yanise Yanise
# 2           1                   Jj Kie
# 3           1             Sakou Younes
# 4           1               راني نعاني
# 7           1  مروان سيدهم سيدهم مروان
# ...       ...                      ...
# 4075      183                    Kà Nø
# 4078      183                  Noé Noé
# 4087      183              Koléa Koléa
# 4093      183              Oussama Zhm
# 4095      183               B-m Lamine
#
#                                                Comments Sentiments
# 1     سلام عليكم ورحمة لديا مشكلة فليكسيت 100 دج و ب...    Negatif
# 2                                    كل عام و انتم بخير    Positif
# 3                                    كل عام و أنتم بخير    Positif
# 4                                     كل عام و حنا بخير    Positif
# 7     كل عام وأنتم بخير وأتمنا رد علا أسإلتي علا لحا...    Positif
# ...                                                 ...        ...
# 4075  ريقلو كونيكسيو غي العاب خسرت شحال من بارطيا عل...    Negatif
# 4078                                         رمضان كريم    Positif
# 4087                                         رمضان كريم    Positif
# 4093  walah cnx ta3koum rahi t3ayi lyamat hadou safi...    Negatif
# 4095  سلام عليكم اوريدو عندي مشكل كل مرة نفليكسي تنح...    Negatif
#
# [3443 rows x 4 columns]

# %%
abbreviations = {
    "mrc": "merci",
    "num": "numéro",
    "numro": "numéro",
    "nn": "non",
    "bn": "bonne",
    "topp": "top",
    "شوي": "قليل",
    "شويا": "قليل",
    "لزونيتي": "رصيد",
    "حنا": "نحن",
    "أسإلتي": "اسئلة",
    "حاص": "خاص",
    "مدام": "بينما",
    "رانا": "نحن",
    "بون": "حسن",
    "توس": "جميع",
    "سبيسيال": "منفرد",
    "سبيال": "منفرد",
    "باه": "لكي",
    "زاف": "كثيرا",
    "بزاف": "كثيرا",
    "نتمني": "نتمنى",
    "فظلكم": "فضلكم",
    "ضلم": "ظلم",
    "ردى": "رد",
    "علاش": "لماذا",
    "علاه": "لماذا",
    "علا": "لماذا",
    "هذ": "هذا",
    "تبرعو": "تبرع",
    "ابليكاسيو": "تطبيق",
    "أبليكاسيون": "تطبيق",
    "أبليكاسيو": "تطبيق",
    "الخاص بكم": "نتاعكم",
    "ديرولنا": "افعلو لنا",
    "ديرو": "افعلو",
    "نحا": "نزع",
    "دير": "افعل",
    "حاجة": "شيء",
    "نتع": "خاص ب",
    "تاع": "خاص ب",
    "تع": "خاص ب",
    "جاوبوني": "رد علي",
    "مشتاركه": "مشاركة",
    "رحو": "اذهبو",
    "هذي": "هذه",
    "يروح": "يذهب",
    "يجي": "يأتي",
    "وقتاه": "متى",
    "وقتاش": "متى",
    "وقتش": "متى",
    "تردولنا": "تردون",
    "نتاع": "خاص ب",
    "شكون": "من",
    "نحيتوها": "نزع",
    "نحيتو": "نزع",
    "نحيت": "نزع",
    "سلفلي": "قرض",
    "سلفولي": "قرض",
    "غدوة": "غدا",
    "تلقى": "تجد",
    "نلقى": "اجد",
    "نأكتيفيها": "تفعيل",
    "نأكتيفي": "تفعيل",
    "ناكتيفي": "تفعيل",
    "نعانيو": "نعانون",
    "نعانو": "نعانون",
    "ميت حال": "رديء",
    "مفهمتش": "لم افهم",
    "انو": "انه",
    "علابالي": "اعلم",
    "ليتو": "اصبحتم",
    "وليتو": "اصبحتم",
    "تدو": "تاخذون",
    "الى": "إلى",
    "خاستني": "احتاج",
    "خستني": "احتاج",
    "مشى": "تعمل",
    "مشا": "تعمل",
    "شكا": "شكوى",
    "شكيت": "شكوى",
    "زرو": "سيء",
    "زيرو": "سيء",
    "سرفيك": "خدمة",
    "سرفيس": "خدمة",
    "جيزي اب": "djezzy app",
    "nchlh": "incha allah",
    "riglou": "regler",
    "bah": "pour",
    "nwaliw": "devenir",
    "مراحش": "لن",
    "مهمش": "ليسو",
    "تعليع": "تعليق",
    "زااف": "كثيرا",
    "khayan": "voleur",
    "djezzyy": "djezzy",
    "ومرديتش": "لم ترد",
    "واش": "ماذا",
    "منبعد": "بعد ذلك",
    "تفتحش": "لا تفتح",
    "ندير": "افعل",
    "راه": "اصبح",
    "لازم": "يجب",
    "pix": "pixx",
    "Twanty": "Twenty",
    "orod": "prod",
    "imtiyaaz": "imtiyaz",
    "tm": "ok",
    "نم": "تم",
    "جداو": "جدا",
    "زلب": "زبل",
    "كونطرا": "عقد",
    "شري": "شراء",
    "توب": "رائع",
    "جزل": "جزيلا",
    "ياسر": "كثيرا",
    "golde": "gold",
    "mknch": "introuvable",
    "rani": "je suis",
    "شكرالكم": "شكرا لكم",
    "viv": "vive",
    "عتل": "ارسل",
    "بعت": "ارسل",
    "لاجونس": "مقر",
    "rpnd": "repond",
    "prv": "prive",
    "svp": "s il vous plais",
    "yennayer": "سنة",
    "amervuh": "سعيدة",
    "assgas": "assegas",
    "asugas": "assegas",
    "asegas": "assegas",
    "amegaz": "amegas",
    "amgaz": "amegas",
    "amegaz": "amegas",
    "amgaz": "amegas",
    "amegaz": "amegas",
    "خخ": "ضحك",
    "هه": "ضحك",
    "سبي": "سبيسيال",
    "شبكهمشكورين": "شبكة مشكورين",
    "يعطيكمصحه": "يعطيكم صحة",
    "نشله": "ان شاء الله",
    "عندوش": "لا يوجد",
    "خفظو": "تخفيض",
    "مليحة": "حسن",
    "مليحه": "حسن",
    "وله": "و الله",
    "مكمات": "مكالمات",
    "وينتا": "متى",
    "تدوها": "تاخذون",
    "felawen": "tous",
    "ya": "il y a",
    "en": "في",
    "panne": "عطل",
    "happy": "سعيدة",
    "koum": "votre",
    "ayi": "faible",
    "new": "جديدة",
    "year": "سنة",
    "years": "سنة",
    "شنو": "ما هو",
    "هدا": "هذا",
    "شالنج": "تحدي",
    "li": "qui",
    "bghi": "aime",
    "ndirlo": "faire",
    "yji": "viens",
    "lah": "pourquoi",
    "raho": "que il",
    "hbs": "arret",
    "بر": "فقط",
    "برك": "فقط",
    "غي": "الا",
    "غير": "الا",
    "الي": "الى",
    "حسنو": "اصلاح",
    "سقمو": "اصلاح",
    "جوند": "legend",
    "يجاند": "legend",
    "ليجند": "legend",
    "علجال": "من أجل",
    "تثقال": "بطء",
    "كون": "ليت",
    "بغى": "اراد",
    "يبغي": "يريد",
    "نبغي": "نريد",
    "تفرج": "مشاهدة",
    "ماتش": "مباراة",
    "رجا": "رجاء",
    "متمشلكش": "لا تعمل",
    "متمسيلكش": "لا تعمل",
    "لايص": "اماكن",
    "بلايص": "اماكن",
    "بلاصة": "اماكن",
    "نسقسي": "اسأل",
    "اذ": "اذا",
    "يمتي": "بلا حدود",
    "اليميتي": "بلا حدود",
    "خسني": "اريد",
    "باطل": "مجانا",
    "قولد": "gold",
    "تعيف": "سيء",
    "نسييو": "محاولة",
    "نلعبو": "لعب",
    "نكونو": "أكون",
    "عب": "لعب",
    "كف": "كيف",
    "اللهيوفقناجميعاقولويارب": "الله يوفقنا جميع اقولو يارب",
    "congratulations": "مبروك",
    "berkaw": "arret",
    "ser": "vole",
    "تردوش": "لا تردون",
    "هضرت": "تكلمت",
    "باش": "لكي",
    "تحلى": "حل",
    "تحلي": "حل",
    "لينا": "لنا",
    "حض": "حظ",
    "wech": "Quoi",
    "ndirou": "faire",
    "bach": "pour",
    "nrebhou": "gagner",
    "elfe": "mille",
    "mabrok": "felicitations",
    "koules": "tous",
    "moucharikones": "participants",
    "el": "les",
    "mabrouk": "مبروك",
    "اطوههالي": "اعطوها لي",
    "شاب": "جميل",
    "يعطيكمالصحة": "يعطيكم الصحة",
    "illa": "lent",
    "woww": "wow",
    "يارب": "يا رب",
    "كلشي": "كل شيء",
    "كنكتي": "تواصل",
    "مانكونيكتيش": "لا أتواصل",
    "يووز": "yooz",
    "يوز": "yooz",
    "وش": "ما هو",
    "وشمن": "اي",
    "ديما": "dima",
    "راه": "انه",
    "معجبتنيش": "سيء",
    "تحبسلي": "توقف",
    "انتاع": "ل",
    "لوس": "plus",
    "شكراوريدو": "شكرا أوريدو",
    "در": "فعل",
    "رهي": "انه",
    "كاين": "يوجد",
    "مباغش": "لا يريد",
    "يمدلي": "يعطيني",
    "يخرجو": "خروج",
    "اكتر": "أكثر",
    "مايمشيش": "لا يعمل",
    "سوايع": "ساعة",
    "محبتش": "لا",
    "جام": "مستحيل",
    "جامي": "مستحيل",
    "تمشلي": "تعمل",
    "ريفي": "خاص",
    "قاع": "كل",
    "منربحش": "لا أربح",
    "منربحوش": "لا أربح",
    "نقارع": "صبر",
    "مفتحتوهاليش": "لا تفتح",
    "ابونمون": "اشتراك",
    "مساج": "رسالة",
    "رجعو": "رد",
    "صحيتو": "شكرا",
    "لاتوجد": "لا توجد",
    "نلقاش": "لا أجد",
    "ما نلقاش": "لا أجد",
    "كريدي": "رصيد",
    "ريبونديولنا": "رد",
    "جد": "جدا",
    "ينحيولي": "نزع",
    "يحذفولي": "نزع",
    "ماسلفت": "لم اقترض",
    "مدايرا": "لم أفعل",
    "راهي": "إنها",
    "فور": "ممتاز",
    "هايل": "ممتاز",
    "مليح": "جيد",
    "شابة": "جميل",
    "ماصلحتليش": "لا تعمل",
    "إستلاف": "قرض",
    "خص": "اريد",
    "هاذ": "هذا",
    "شحال": "كم",
    "تاكتيفيه": "تفعيل",
    "حتان": "كي",
    "كيفاش": "كيف",
    "غلطة": "خطا",
    "ختاريت": "خيار",
    "ديالي": "خاص بي",
    "حاب": "اريد",
    "ويل": "أو",
    "ابعث": "ارسال",
    "goold": "gold",
    "ماتجاوبوش": "عدم رد",
    "مهدى": "هدية",
    "واشهرالجاي": "شهر موالي",
    "نخلصش": "لا أدفع",
    "ابليس": "plus",
    "تأكتيفها": "تفعيل",
    "هيل": "hayla",
    "هاذي": "هذه",
    "وشمن": "ما هي",
    "جزاير": "جزائر",
    "معن": "معنى",
    "فاه": "فيها",
    "فاش": "اي",
    "مكوبي": "مقطوع",
    "مي": "لكن",
    "مايمشيلك": "لا يعمل",
    "نديرلهم": "اعمل لهم",
    "تتمسخرو": "استهزاء",
    "ريبونديو": "رد",
    "plais" : "من فظلكم",
    "كفاه": "كيف",
    "ندموندي": "طلب",
    "دخلتو": "ادخال",
    "العالميه": "عالمية",
    "قات": "بقي",
    "بقات": "بقي",
    "nechlh": "incha allah",
    "jdida": "جديد",
    "كيفما": "كيف",
    "اندير": "افعل",
    "ذيم": "دائما",
    "وين": "أين",
    "راهي": "هي",
    "ماندمت": "ندم",
    "حشو": "خدعة",
    "حشوة": "خدعة",
    "انشاءاللهتكونمننصيبي": "ان شاء الله تكون من نصيبي",
    "نتمنالهم": "اتمنى",
    "راحوش": "لم يذهب",
    "بادن": "باذن",
    "الي": "الذي",
    "تغلقلو": "غلق",
    "نيمروه": "رقم",
    "يسترجعو": "استرجاع",
    "رانيني": "ranini",
    "عقوبة": "عاقبة",
    "قوب": "عاقبة",
    "حطو": "وضع",
    "لينا": "لنا",
    "ستمرار": "مستمر",
    "لابيلكاسيو": "تطبيق",
    "لبليكاسيو": "تطبيق",
    "متمشيش": "لا تعمل",
    "حبستوها": "توقف",
    "حمال": "تحميل",
    "مزان": "ميزان",
    "جيه": "جهة",
    "فلاترددو": "فلا تترددو",
    "خدمهوعروضاطاقم": "خدمة و عروض طاقم",
    "فلعاصمة": "في عاصمة",
    "nztjwice": " ",
    "refvf": " ",
    "b": " ",
    "br": " ",
    "ابار": "يبارك",
    "يحفضكم": "يحفظكم",
    "يلوس": "plus",
    "تاه": "متى",
    "بف": " ",
    "sagmou": "regler",
    "شويش": "switch",
    "بغية": "اريد",
    "dialkom": "vous",
    "sahel": "facile",
    "toop": "top",
    "هنيء": "مبروك",
    "puse": "sim",
    "pui": "puis",
    "nerbah": "gagne",
    "ghir": "sauf",
    "بيان": "جيدا",
    "ماتمشيش": "لا تعمل",
    "نحافضو": "حفاظ",
    "تخلاص": "انتهاء",
    "متعرفش": "لا تعلم",
    "خاصتا": "خاصة",
    "وفى": "و في",
    "ظل": "دائما",
    "مدرتو": "لم تفعلو",
    "لموبليس": "موبيليس",
    "را": "انه",
    "صر": "حدث",
    "rah": "il est",
    "gae": "tous",
    "dok": "maintenant",
    "لابليكاسيون": "تطبيق",
    "كلش": "كل",
    "مشاءالله": "ما شاء الله",
    "حبس": "توقف",
    "زيد": "ايضا",
    "تسرقو": "سرق",
    "تاكتيفي": "تفعيل",
    "زوعاماء": "زعماء",
    "ul": " ",
    "كدب": "كذب",
    "ميقراسيون": "تبديل",
    "شح": "كم",
    "فيهاش": "لا يوجد",
    "نجاوب": "اجيب",
    "راحت": "ذهب",
    "متسواش": "سيء",
    "تعكم": "خاص بكم",
    "حقاهايلة": "ممتاز",
    "صرقولي": "سرق",
    "صرق": "سرق",
    "ويني": "اين",
    "حمدلله": "حمد لله",
    "رحمن": "رحمان",
    "نشال": "شاء الله",
    "ماشاء": "ما شاء",
    "تنحولي": "نزع",
    "خمسلاف": "خمسة ألف",
    "خمسلاف": "خمسة ألف",
    "مفعلتهاش": "لا تفعيل",
    "سرقتولي": "سرق",
    "لكريدي": "رصيد",
    "انترنتوراها": "اين انترنت",
    "تعييف": "سيء",
    "تعيف": "سيء",
    "ضك": "الان",
    "جزى": "جزاك",
    "نشاء": "ان شاء",
    "إنشاءالله": "ان شاء الله",
    "نشالله": "ان شاء الله",
    "شاءالله": "شاء الله"
}

def replace_abbreviations(text):
    words = text.split()
    return ' '.join([abbreviations[word] if word in abbreviations else word for word in words])

comments_df['Comments'] = comments_df['Comments'].apply(replace_abbreviations)

# %%
from collections import defaultdict
import re

# Dictionnaire de regroupement phonétique
phonetic_groups = {
    "تعبئة": ["كنفليكسيو", "نفليكسي", "نفليكسيو", "فليكس", "تفليكسي", "فليكسولنا", "نفلبكسى", "فليكسيت", "كسي", "فليكسي"],
    "connexion": ["conx", "cnx", "ncx", "conexion", "connection"],
    "reseau": ["wrizo", "rizo", "riso", "rysou", "resou", "risou"],
    "اصلحوا": ["ريقلوه", "ريقلو", "صلحو", "ريقولو", "صلحونا", "عدلو", "ريغلونا", "رقليو", "تريغليونا", "لوتصلحولينا", "تريقلونا", "وريقليو"],
    "شبكة": ["ريزو", "اريزو", "الريزو", "ااريزو", "خط", "خطي", "رزو"],
    "ما به": ["واشي", "وشبيه", "شبيه"],
    "لا يوجد": ["ماكاش", "مكانش", "مكاش", "مكااش", "والو", "معنديش", "الو"],
    "أي": ["كش", "كاش"],
    "انترنت": ["كونيكسيون", "كونكسيو", "كونكزيون", "كونيكسيو", "ليدوني", "انترنات", "انترنيت","نترنت", "أنترنات", "الكنكسيو", "الانثرنات", "الانترنت", "أنترنت",  "اترنات", "الكونيكسيوو", "نت", "لكونيكسيو", "كنكسيو", "كونيكسو", "انترن"],
    "جازي": ["جايز", "جاز", "دجيزي", "دجزي", "جيزي", "جايزي"],
    "اسقاس": ["اسوكاس", "اصكاس", "اسيقاس", "اسكاس"],
    "امقاز": ["أموقاز", "امكاز"],
    "رمز": ["كود", "رزم"],
    "بارك": ["بارى", "بيار", "باراك", "يبارك"],
    "شريحة": ["لابيس", "لبيس", "بيس", "لابوس", "لبييس", "ليبيس", "بوس", "سبيسي", "لبووس", "pis"],
    "اوريدو": ["اريدوو", "لأوريد", "ياؤريدوا", "اوريدوا", "واوريدو", "ااوريدو", "اريدو"],
    "ان شاء": ["إنشاء", "نشالله", "انشاء"],
    "ilimite": ["ilm", "ilmt", "ilimiti", "ilim"],
}

# Création d’un mapping inverse (pour accélérer la recherche)
phonetic_mapping = {}
for standard, variations in phonetic_groups.items():
    for variant in variations:
        phonetic_mapping[variant] = standard

# Fonction de remplacement des variantes phonétiques
def replace_phonetic_variants(text):
    words = text.split()
    return ' '.join([phonetic_mapping[word] if word in phonetic_mapping else word for word in words])

comments_df['Comments'] = comments_df['Comments'].apply(replace_phonetic_variants)

# %%
comments_df["Comments"][1]
# Out:
# 'سلام عليكم ورحمة لديا مشكلة تعبئة 100 دج و بدأت تنقص قليل قليل من 100 دج إلى 75دج و بعدها إلى 50 دج و بعدها إلى 25 دج اين ذهبت رصيد تاعي لن أتكلم بها و لم اتصل بها و ليس لي خاصية رنتي اذن اين ذهب مالي و صار نفس الشيء مع أخي ماهذا لابد من استرجاعه'

# %%
# Add ID column to comments_df
comments_df.insert(0, 'ID Comment', range(1, 1 + len(comments_df)))
comments_df
# Out:
#       ID Comment  ID Post                User Name  \
# 1              1        1            Yanise Yanise
# 2              2        1                   Jj Kie
# 3              3        1             Sakou Younes
# 4              4        1               راني نعاني
# 7              5        1  مروان سيدهم سيدهم مروان
# ...          ...      ...                      ...
# 4075        3439      183                    Kà Nø
# 4078        3440      183                  Noé Noé
# 4087        3441      183              Koléa Koléa
# 4093        3442      183              Oussama Zhm
# 4095        3443      183               B-m Lamine
#
#                                                Comments Sentiments
# 1     سلام عليكم ورحمة لديا مشكلة تعبئة 100 دج و بدأ...    Negatif
# 2                                    كل عام و انتم بخير    Positif
# 3                                    كل عام و أنتم بخير    Positif
# 4                                     كل عام و نحن بخير    Positif
# 7     كل عام وأنتم بخير وأتمنا رد لماذا اسئلة لماذا ...    Positif
# ...                                                 ...        ...
# 4075  اصلحوا انترنت الا العاب خسرت كم من بارطيا من أ...    Negatif
# 4078                                         رمضان كريم    Positif
# 4087                                         رمضان كريم    Positif
# 4093  walah connexion ta3koum rahi t3ayi lyamat hado...    Negatif
# 4095  سلام عليكم اوريدو عندي مشكل كل مرة تعبئة نزع خ...    Negatif
#
# [3443 rows x 5 columns]

# %%
import os

# Vérification du format attendu
assert 'ID Comment' in comments_df.columns and 'Comments' in comments_df.columns, "Les colonnes 'ID Comment' et 'Comments' doivent exister."

# Créer le dossier de résultats
os.makedirs('/content/Results', exist_ok=True)

# %%
# Installer la bibliothèque pour exécuter GGUF
# %pip install llama-cpp-python tqdm

from llama_cpp import Llama
# Out:
# Collecting llama-cpp-python
#   Downloading llama_cpp_python-0.3.8.tar.gz (67.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 MB 10.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (4.67.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.11/dist-packages (from llama-cpp-python) (4.13.2)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.11/dist-packages (from llama-cpp-python) (2.0.2)
# Collecting diskcache>=5.6.1 (from llama-cpp-python)
#   Downloading diskcache-5.6.3-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: jinja2>=2.11.3 in /usr/local/lib/python3.11/dist-packages (from llama-cpp-python) (3.1.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2>=2.11.3->llama-cpp-python) (3.0.2)
# Downloading diskcache-5.6.3-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 3.1 MB/s eta 0:00:00
# Building wheels for collected packages: llama-cpp-python
#   Building wheel for llama-cpp-python (pyproject.toml) ... done
#   Created wheel for llama-cpp-python: filename=llama_cpp_python-0.3.8-cp311-cp311-linux_x86_64.whl size=5959619 sha256=d3306e8df6efacc937768f0fccd1aa82aafe4dba7d9b4c669546eca93fdf6b1e
#   Stored in directory: /root/.cache/pip/wheels/c0/03/66/eb3810eafd55d921b2be32896d1f44313996982360663aa80b
# Successfully built llama-cpp-python
# Installing collected packages: diskcache, llama-cpp-python
# Successfully installed diskcache-5.6.3 llama-cpp-python-0.3.8

# %%
# Créer le dossier de modèle
os.makedirs('/content/models', exist_ok=True)

# !wget -O /content/models/DeepSeek-R1-Distill-Qwen-7B-Q6_K.gguf \
"https://huggingface.co/lmstudio-community/DeepSeek-R1-Distill-Qwen-7B-GGUF/resolve/main/DeepSeek-R1-Distill-Qwen-7B-Q6_K.gguf"
# Out:
# --2025-04-19 19:40:03--  https://huggingface.co/lmstudio-community/DeepSeek-R1-Distill-Qwen-7B-GGUF/resolve/main/DeepSeek-R1-Distill-Qwen-7B-Q6_K.gguf
# Resolving huggingface.co (huggingface.co)... 3.168.73.111, 3.168.73.106, 3.168.73.38, ...
# Connecting to huggingface.co (huggingface.co)|3.168.73.111|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://cdn-lfs-us-1.hf.co/repos/05/84/058408ebba13ec9fd4556e4187361bb25387663d5ec87e73d85e1abca50bb887/b05e9a3c531cf0ff7ba3ab96c78bfdb68a664e50859ac1245d6322873ff21a7b?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27DeepSeek-R1-Distill-Qwen-7B-Q6_K.gguf%3B+filename%3D%22DeepSeek-R1-Distill-Qwen-7B-Q6_K.gguf%22%3B&Expires=1745095203&Policy=&Signature=LGIXeY6oIrWsXvhdu-gzmXnXphoaMn7PVjDpGd8PzeUE%7EVELaa5x2WDaFaCoxfUjlzGBIjtLCOzu-lS5--M9ukwML1Qdo1-4NAEKeMZjqj4SPJfxlcSeDsMAYmDnGVS5ai-vj8c2cksUY1ECSUUbFCFEAu0Vi81EaKA7NYmK17nSb5R4NEQlimWMcXPXjZhvcs-SlvrmAls9%7EwJ4iySR2Mbk8BwacRNRCS%7EZUoBPRFfG3FxmxdSzgDzOI49R%7EQJa4NSF1t1nUVXmTNBvWEruCMNE%7EifTCz%7E8vq7kBhMg2F9x5V62MMDqKAKI6yqstR36f3EjLUcWHBWSt48dc4d0Iw__&Key-Pair-Id=K24J24Z295AEI9 [following]
# --2025-04-19 19:40:03--  https://cdn-lfs-us-1.hf.co/repos/05/84/058408ebba13ec9fd4556e4187361bb25387663d5ec87e73d85e1abca50bb887/b05e9a3c531cf0ff7ba3ab96c78bfdb68a664e50859ac1245d6322873ff21a7b?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27DeepSeek-R1-Distill-Qwen-7B-Q6_K.gguf%3B+filename%3D%22DeepSeek-R1-Distill-Qwen-7B-Q6_K.gguf%22%3B&Expires=1745095203&Policy=&Signature=LGIXeY6oIrWsXvhdu-gzmXnXphoaMn7PVjDpGd8PzeUE%7EVELaa5x2WDaFaCoxfUjlzGBIjtLCOzu-lS5--M9ukwML1Qdo1-4NAEKeMZjqj4SPJfxlcSeDsMAYmDnGVS5ai-vj8c2cksUY1ECSUUbFCFEAu0Vi81EaKA7NYmK17nSb5R4NEQlimWMcXPXjZhvcs-SlvrmAls9%7EwJ4iySR2Mbk8BwacRNRCS%7EZUoBPRFfG3FxmxdSzgDzOI49R%7EQJa4NSF1t1nUVXmTNBvWEruCMNE%7EifTCz%7E8vq7kBhMg2F9x5V62MMDqKAKI6yqstR36f3EjLUcWHBWSt48dc4d0Iw__&Key-Pair-Id=K24J24Z295AEI9
# Resolving cdn-lfs-us-1.hf.co (cdn-lfs-us-1.hf.co)... 18.173.218.115, 18.173.218.28, 18.173.218.111, ...
# Connecting to cdn-lfs-us-1.hf.co (cdn-lfs-us-1.hf.co)|18.173.218.115|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6254198464 (5.8G) [binary/octet-stream]
# Saving to: ‘/content/models/DeepSeek-R1-Distill-Qwen-7B-Q6_K.gguf’
#
# /content/models/Dee 100%[===================>]   5.82G   218MB/s    in 32s
#
# 2025-04-19 19:40:35 (185 MB/s) - ‘/content/models/DeepSeek-R1-Distill-Qwen-7B-Q6_K.gguf’ saved [6254198464/6254198464]

# %%
from llama_cpp import Llama

llm = Llama(
    model_path="/content/models/DeepSeek-R1-Distill-Qwen-7B-Q6_K.gguf",
    n_gpu_layers=-1,  # Utilise toutes les couches sur le GPU
    use_mlock=False,
    n_ctx=2048,
    verbose=False
)
# Out:
# llama_init_from_model: n_ctx_per_seq (2048) < n_ctx_train (131072) -- the full capacity of the model will not be utilized

# %%
system_prompt = (
    "You are a highly intelligent multilingual assistant specialized in **telecom customer feedback classification**. "
    "Your job is to analyze each customer comment, identified by its **unique ID**, and classify it into one or more **appropriate subcategories** based on the content.\n\n"

    "### 🎯 Classification Subcategories:\n"
    "- **Call Quality Issues** (e.g., Dropped calls, Voice distortion, Call connection failures, Can't hear the other person)\n"
    "- **Data Quality Issues (3G, 4G)** (e.g., Slow internet or something is slow, No connection, Intermittent connectivity, Mobile data not working properly)\n"
    "- **Coverage Issues** (e.g., Weak signal, Dead zones, No service in certain areas, Network outages in cities or villages)\n"
    "- **Response Time** (e.g., Slow customer support response, Long wait times on hotline or chat, Delayed service resolution)\n"
    "- **Agent Behavior** (e.g., Rude or unhelpful agents, Lack of knowledge, Unprofessional attitude, Didn’t solve my problem)\n"
    "- **Overcharging and Stolen Credit Issues** (e.g., Unexpected charges, Credit deducted without usage, Sudden balance loss after recharge)\n"
    "- **Billing Errors** (e.g., Wrong invoice details, Duplicate charges, Inaccurate amounts shown on bill, Postpaid billing problems)\n"
    "- **Subscription & Plan Issues** (e.g., Forced subscriptions, Plan switched without consent, Unwanted service activation, Difficult to unsubscribe)\n"
    "- **Hidden Charges** (e.g., Unclear pricing, Unexpected fees, Not informed about deductions, Surprise costs after service use)\n"
    "- **Suggestions** (e.g., Add 5G, Improve offers, Lower prices, Requesting better bundles or roaming options)\n"
    "- **Promotions & Discounts** (e.g., Misleading promotions, No actual benefit, Ads say something else, Discounts not applied)\n"
    "- **Competitor Pricing & Value (Mobilis and Djezzy)** (e.g., Better pricing or deals from competitors, More data or minutes for the same price)\n"
    "- **Competitor Plan Flexibility (Mobilis and Djezzy)** (e.g., More customizable plans by competitors, Ability to build own bundles)\n"
    "- **Competitor Data Consumption (Mobilis and Djezzy)** (e.g., Faster data exhaustion compared to competitors, My data lasts longer on Djezzy)\n"
    "- **Loyalty Expression** (e.g., Well done, Good service, Satisfied customer, Happy New Year, Saha Ramdankom, Thank you messages)\n"
    "- **Service Information Request** (e.g., What is the code for loan? How to activate roaming? How to check balance? Questions about using a service or feature)\n"
    "- **Other** (e.g., Irrelevant, incomprehensible, sarcasm, unrelated comment, joke or spam)\n\n"


    "### 🧠 Classification Instructions:\n"
    "1. Carefully read the content of each comment.\n"
    "2. Determine which subcategories best represent the issue(s).\n"
    "3. Multiple subcategories are allowed when relevant and even encouraged when multiple issues are present.\n"
    "4. DO NOT limit to one category if the comment contains multiple concerns.\n"

    "### 📤 Output Format:\n"
    "Respond **strictly** using the following JSON structure (no extra explanations):\n\n"
      "{\n"
      "  \"45\": {\n"
      "    \"categories\": [\"Promotions & Discounts\", \"Suggestions\"]\n"
      "  },\n"
      "  \"69\": {\n"
      "    \"categories\": [\"Call Quality Issues\"]\n"
      "  }\n"
      "}\n\n"

    "⚠️ **Important Notes**:\n"
    "- Do NOT include any commentary or explanation in the output.\n"
    "- Always use the exact category labels listed above.\n"
    "- Do NOT invent new categories.\n"
    "- Ensure output is in **valid JSON format**.\n"
    "- Each comment ID must map to at least one subcategory.\n\n"

    "### 🌐 Supported Languages:\n"
    "- Arabic (العربية)\n"
    "- Algerian Darija (الدارجة الجزائرية)\n"
    "- French (Français)\n"
    "- English\n\n"

    "Proceed with the classification."
)

# %%
# Prendre seulement les 100 premiers commentaires pour le test
test_df = comments_df.head(100).copy()
test_df
# Out:
#      ID Comment  ID Post                  User Name  \
# 1             1        1              Yanise Yanise
# 2             2        1                     Jj Kie
# 3             3        1               Sakou Younes
# 4             4        1                 راني نعاني
# 7             5        1    مروان سيدهم سيدهم مروان
# ..          ...      ...                        ...
# 108          96        4               Принц Князья
# 109          97        4  ياسين ميمز - Yassine mems
# 110          98        4                   عبد الحق
# 111          99        4                   Ämïnë Mø
# 112         100        4                   Ďøģ Māðð
#
#                                               Comments Sentiments
# 1    سلام عليكم ورحمة لديا مشكلة تعبئة 100 دج و بدأ...    Negatif
# 2                                   كل عام و انتم بخير    Positif
# 3                                   كل عام و أنتم بخير    Positif
# 4                                    كل عام و نحن بخير    Positif
# 7    كل عام وأنتم بخير وأتمنا رد لماذا اسئلة لماذا ...    Positif
# ..                                                 ...        ...
# 108  جازي افعلو هدة حسن كي شغل مسابقة ليروح يتفرج ل...    Positif
# 109                           و نتوما مديرولناش مسابقة     Neutre
# 110                 عاشت الجزائر عربية مسلمة إلى الابد    Positif
# 111                              ما به تطبيق محبش يدخل    Negatif
# 112                             تطبيقكم لا يعمل اصلحوه    Negatif
#
# [100 rows x 5 columns]

# %%
# Extraire uniquement les commentaires dont l'ID_Comment est entre 1519 et 2000 inclus
test_df = comments_df[(comments_df["ID Comment"] >= 1519) & (comments_df["ID Comment"] <= 2000)].copy()

# Aperçu du DataFrame filtré
test_df
# Out:
#       ID Comment  ID Post                User Name  \
# 1708        1519       87        Semouda La Frappe
# 1709        1520       87           HÎc Hàm Ÿã Hïà
# 1710        1521       87               Mã Sï Bras
# 1711        1522       87          Hicham Merhouni
# 1712        1523       87                لحظه وداع
# ...          ...      ...                      ...
# 2281        1996      110            Yanis Meziani
# 2282        1997      110                   Zö Làa
# 2283        1998      110                    Ám Àr
# 2284        1999      110              Ayoup Ayoub
# 2285        2000      110  Fãhîmã Souhil Ouldhabib
#
#                                                Comments Sentiments
# 1708                 بالنسبة pixx pro لا يوجد هذا العرض     Neutre
# 1709                                    صح رمضانك إيمان    Positif
# 1710                                     ب كم العرض هذا     Neutre
# 1711            باتوفيق شكلو 600 تلقاوها في العرض الأول     Neutre
# 1712       مكن سوال هل صح لمي تروح لعمرة يبقبي يعمل ولا     Neutre
# ...                                                 ...        ...
# 2281  مضاعفة حجم انترنت في فترة كأس افريقيا ستكون فك...    Positif
# 2282                                     rj3olna reseau    Negatif
# 2283  أتمنى أن تكون المفاجأة رحلة إلى كوت ديفوار عن ...     Neutre
# 2284           ماذا من شريحة حسن في اوريدو ليعرف ينصحنا     Neutre
# 2285              bonne chance a notre equipe nationale     Neutre
#
# [482 rows x 5 columns]

# %%
import json
import re
from tqdm import tqdm
from time import sleep

# Boucle d’inférence
results = {}

for idx, row in test_df.iterrows():
    comment_id = str(row['ID Comment'])
    comment_text = str(row['Comments'])

    prompt = (
        system_prompt
        + f"\n\nClassify the following customer comment. Respond using ONLY the JSON format.\n"
        + f"Comment ID: \"{comment_id}\"\n"
        + f"Comment: \"{comment_text}\"\n"
        + "\nDO NOT limit to one category if the content contains multiple concerns.\n"
        + "\nReturn the result in this exact structure:\n"
        + "{\n"
        + f"  \"{comment_id}\": {{\n"
        + "    \"categories\": [\"Category A\", \"Category B\"]\n"
        + "  }\n"
        + "}\n"
        + "\n⚠️ DO NOT COMMENT. DO NOT THINK. ONLY RETURN STRICT JSON."
    )

    try:
        output = llm(prompt, max_tokens=256, temperature=0.0)
        raw_response = output["choices"][0]["text"].strip()

        # Extraction du JSON
        json_match = re.search(r"\{.*\}", raw_response, re.DOTALL)
        if json_match:
            json_str = json_match.group()
            parsed = json.loads(json_str)
            results.update(parsed)
            print(json.dumps(parsed, indent=2, ensure_ascii=False))  # 👈 Affichage formaté JSON uniquement
        else:
            raise ValueError("No JSON found")

    except Exception:
        fallback = {
            comment_id: {
                "categories": ["Other"]
            }
        }
        results.update(fallback)
        print(json.dumps(fallback, indent=2, ensure_ascii=False))

    sleep(0.5)
# Out:
# {
#   "1519": {
#     "categories": [
#       "Promotions & Discounts"
#     ]
#   }
# }
# {
#   "1520": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1521": {
#     "categories": [
#       "Suggestions",
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1522": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1523": {
#     "categories": [
#       "Suggestions",
#       "Service Information Request"
#     ]
#   }
# }
# {
#   "1524": {
#     "categories": [
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1525": {
#     "categories": [
#       "Subscription & Plan Issues"
#     ]
#   }
# }
# {
#   "1526": {
#     "categories": [
#       "Promotions & Discounts",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1527": {
#     "categories": [
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1528": {
#     "categories": [
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1529": {
#     "categories": [
#       "Overcharging and Stolen Credit Issues"
#     ]
#   }
# }
# {
#   "1530": {
#     "categories": [
#       "Suggestions",
#       "Service Information Request"
#     ]
#   }
# }
# {
#   "1531": {
#     "categories": [
#       "Suggestions",
#       "Service Information Request"
#     ]
#   }
# }
# {
#   "1532": {
#     "categories": [
#       "Suggestions",
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1533": {
#     "categories": [
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1534": {
#     "categories": [
#       "Suggestions",
#       "Overcharging and Stolen Credit Issues"
#     ]
#   }
# }
# {
#   "1535": {
#     "categories": [
#       "Service Information Request"
#     ]
#   }
# }
# {
#   "1536": {
#     "categories": [
#       "Coverage Issues"
#     ]
#   }
# }
# {
#   "1537": {
#     "categories": [
#       "Suggestions",
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1538": {
#     "categories": [
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1539": {
#     "categories": [
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1540": {
#     "categories": [
#       "Promotions & Discounts",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1541": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1542": {
#     "categories": [
#       "Data Quality Issues (3G, 4G)",
#       "Coverage Issues"
#     ]
#   }
# }
# {
#   "1543": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1544": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1545": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1546": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1547": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1548": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1549": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1550": {
#     "categories": [
#       "Suggestions",
#       "Overcharging and Stolen Credit Issues"
#     ]
#   }
# }
# {
#   "1551": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1552": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1553": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1554": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1555": {
#     "categories": [
#       "Suggestions",
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1556": {
#     "categories": [
#       "Other"
#     ]
#   }
# }
# {
#   "1557": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1558": {
#     "categories": [
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1559": {
#     "categories": [
#       "Other"
#     ]
#   }
# }
# {
#   "1560": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1561": {
#     "categories": [
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1562": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1563": {
#     "categories": [
#       "Competitor Pricing & Value (Mobilis and Djezzy)",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1564": {
#     "categories": [
#       "Coverage Issues",
#       "Call Quality Issues"
#     ]
#   }
# }
# {
#   "1565": {
#     "categories": [
#       "Coverage Issues",
#       "Service Information Request"
#     ]
#   }
# }
# {
#   "1566": {
#     "categories": [
#       "Competitor Plan Flexibility (Mobilis and Djezzy)",
#       "Competitor Data Consumption (Mobilis and Djezzy)"
#     ]
#   }
# }
# {
#   "1567": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1568": {
#     "categories": [
#       "Suggestions",
#       "Other"
#     ]
#   }
# }
# {
#   "1569": {
#     "categories": [
#       "Suggestions",
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1570": {
#     "categories": [
#       "Data Quality Issues (3G, 4G)",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1571": {
#     "categories": [
#       "Other"
#     ]
#   }
# }
# {
#   "1572": {
#     "categories": [
#       "Suggestions",
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1573": {
#     "categories": [
#       "Suggestions",
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1574": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1575": {
#     "categories": [
#       "Suggestions",
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1576": {
#     "categories": [
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1577": {
#     "categories": [
#       "Data Quality Issues (3G, 4G)"
#     ]
#   }
# }
# {
#   "1578": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1579": {
#     "categories": [
#       "Competitor Plan Flexibility (Mobilis and Djezzy)",
#       "Competitor Data Consumption (Mobilis and Djezzy)"
#     ]
#   }
# }
# {
#   "1580": {
#     "categories": [
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1581": {
#     "categories": [
#       "Sarcasm",
#       "Irrelevant"
#     ]
#   }
# }
# {
#   "1582": {
#     "categories": [
#       "Other"
#     ]
#   }
# }
# {
#   "1583": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1584": {
#     "categories": [
#       "Suggestions",
#       "Service Information Request"
#     ]
#   }
# }
# {
#   "1585": {
#     "categories": [
#       "Suggestions",
#       "Other"
#     ]
#   }
# }
# {
#   "1586": {
#     "categories": [
#       "Service Information Request"
#     ]
#   }
# }
# {
#   "1587": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1588": {
#     "categories": [
#       "Other"
#     ]
#   }
# }
# {
#   "1589": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1590": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1591": {
#     "categories": [
#       "Sarcasm",
#       "Irrelevant"
#     ]
#   }
# }
# {
#   "1592": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1593": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1594": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1595": {
#     "categories": [
#       "Service Information Request",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1596": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1597": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1598": {
#     "categories": [
#       "Promotions & Discounts"
#     ]
#   }
# }
# {
#   "1599": {
#     "categories": [
#       "Suggestions",
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1600": {
#     "categories": [
#       "Other"
#     ]
#   }
# }
# {
#   "1601": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1602": {
#     "categories": [
#       "Promotions & Discounts"
#     ]
#   }
# }
# {
#   "1603": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1604": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1605": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1606": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1607": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1608": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1609": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1610": {
#     "categories": [
#       "Loyalty Expression",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1611": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1612": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1613": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1614": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1615": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1616": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1617": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1618": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1619": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1620": {
#     "categories": [
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1621": {
#     "categories": [
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1622": {
#     "categories": [
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1623": {
#     "categories": [
#       "Suggestions",
#       "Overcharging and Stolen Credit Issues"
#     ]
#   }
# }
# {
#   "1624": {
#     "categories": [
#       "Competitor Pricing & Value (Mobilis and Djezzy)",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1625": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1626": {
#     "categories": [
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1627": {
#     "categories": [
#       "Coverage Issues"
#     ]
#   }
# }
# {
#   "1628": {
#     "categories": [
#       "Suggestions",
#       "Service Information Request"
#     ]
#   }
# }
# {
#   "1629": {
#     "categories": [
#       "Competitor Pricing & Value (Mobilis and Djezzy)",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1630": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1631": {
#     "categories": [
#       "Subscription & Plan Issues",
#       "Promotions & Discounts"
#     ]
#   }
# }
# {
#   "1632": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1633": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1634": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1635": {
#     "categories": [
#       "Coverage Issues",
#       "Data Quality Issues (3G, 4G)"
#     ]
#   }
# }
# {
#   "1636": {
#     "categories": [
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1637": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1638": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1639": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1640": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1641": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1642": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1643": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1644": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1645": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1646": {
#     "categories": [
#       "Competitor Pricing & Value (Mobilis and Djezzy)",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1647": {
#     "categories": [
#       "Other"
#     ]
#   }
# }
# {
#   "1648": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1649": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1650": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1651": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1652": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1653": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1654": {
#     "categories": [
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1655": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1656": {
#     "categories": [
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1657": {
#     "categories": [
#       "Competitor Plan Flexibility (Mobilis and Djezzy)",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1658": {
#     "categories": [
#       "Coverage Issues"
#     ]
#   }
# }
# {
#   "1659": {
#     "categories": [
#       "Service Information Request"
#     ]
#   }
# }
# {
#   "1660": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1661": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1662": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1663": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1664": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1665": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1666": {
#     "categories": [
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1667": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1668": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1669": {
#     "categories": [
#       "Agent Behavior",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1670": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1671": {
#     "categories": [
#       "Promotions & Discounts",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1672": {
#     "categories": [
#       "Coverage Issues",
#       " suggestions"
#     ]
#   }
# }
# {
#   "1673": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1674": {
#     "categories": [
#       "Agent Behavior"
#     ]
#   }
# }
# {
#   "1675": {
#     "categories": [
#       "Competitor Pricing & Value (Mobilis and Djezzy)"
#     ]
#   }
# }
# {
#   "1676": {
#     "categories": [
#       "Suggestions",
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1677": {
#     "categories": [
#       "Loyalty Expression",
#       "Service Information Request"
#     ]
#   }
# }
# {
#   "1678": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1679": {
#     "categories": [
#       "Coverage Issues"
#     ]
#   }
# }
# {
#   "1680": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1681": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1682": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1683": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1684": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1685": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1686": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1687": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1688": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1689": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1690": {
#     "categories": [
#       "Coverage Issues",
#       " suggestions"
#     ]
#   }
# }
# {
#   "1691": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1692": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1693": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1694": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1695": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1696": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1697": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1698": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1699": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1700": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1701": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1702": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1703": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1704": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1705": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1706": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1707": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1708": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1709": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1710": {
#     "categories": [
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1711": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1712": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1713": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1714": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1715": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1716": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1717": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1718": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1719": {
#     "categories": [
#       "Coverage Issues",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1720": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1721": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1722": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1723": {
#     "categories": [
#       "Suggestions",
#       "Competitor Pricing & Value (Mobilis and Djezzy)"
#     ]
#   }
# }
# {
#   "1724": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1725": {
#     "categories": [
#       "Coverage Issues",
#       "Call Quality Issues"
#     ]
#   }
# }
# {
#   "1726": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1727": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1728": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1729": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1730": {
#     "categories": [
#       "Coverage Issues",
#       "Call Quality Issues"
#     ]
#   }
# }
# {
#   "1731": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1732": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1733": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1734": {
#     "categories": [
#       "Promotions & Discounts",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1735": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1736": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1737": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1738": {
#     "categories": [
#       "Suggestions",
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1739": {
#     "categories": [
#       "Other"
#     ]
#   }
# }
# {
#   "1740": {
#     "categories": [
#       "Suggestions",
#       "Overcharging and Stolen Credit Issues"
#     ]
#   }
# }
# {
#   "1741": {
#     "categories": [
#       "Service Information Request"
#     ]
#   }
# }
# {
#   "1742": {
#     "categories": [
#       "Competitor Pricing & Discounts",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1743": {
#     "categories": [
#       "Suggestions",
#       "Service Information Request"
#     ]
#   }
# }
# {
#   "1744": {
#     "categories": [
#       "Suggestions",
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1745": {
#     "categories": [
#       "Promotions & Discounts",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1746": {
#     "categories": [
#       "Suggestions",
#       "Service Information Request"
#     ]
#   }
# }
# {
#   "1747": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1748": {
#     "categories": [
#       "Suggestions",
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1749": {
#     "categories": [
#       "Promotions & Discounts",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1750": {
#     "categories": [
#       "Data Quality Issues (3G, 4G)",
#       "Coverage Issues"
#     ]
#   }
# }
# {
#   "1751": {
#     "categories": [
#       "Coverage Issues"
#     ]
#   }
# }
# {
#   "1752": {
#     "categories": [
#       "Suggestions",
#       "Service Information Request"
#     ]
#   }
# }
# {
#   "1753": {
#     "categories": [
#       "Coverage Issues"
#     ]
#   }
# }
# {
#   "1754": {
#     "categories": [
#       "Coverage Issues"
#     ]
#   }
# }
# {
#   "1755": {
#     "categories": [
#       "Suggestions",
#       "Other"
#     ]
#   }
# }
# {
#   "1756": {
#     "categories": [
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1757": {
#     "categories": [
#       "Suggestions",
#       "Service Information Request"
#     ]
#   }
# }
# {
#   "1758": {
#     "categories": [
#       "Suggestions",
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1759": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1760": {
#     "categories": [
#       "Suggestions",
#       "Other"
#     ]
#   }
# }
# {
#   "1761": {
#     "categories": [
#       "Coverage Issues"
#     ]
#   }
# }
# {
#   "1762": {
#     "categories": [
#       "Loyalty Expression",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1763": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1764": {
#     "categories": [
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1765": {
#     "categories": [
#       "Coverage Issues",
#       "Data Quality Issues (3G, 4G)"
#     ]
#   }
# }
# {
#   "1766": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1767": {
#     "categories": [
#       "Loyalty Expression",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1768": {
#     "categories": [
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1769": {
#     "categories": [
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1770": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1771": {
#     "categories": [
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1772": {
#     "categories": [
#       "Agent Behavior"
#     ]
#   }
# }
# {
#   "1773": {
#     "categories": [
#       "Coverage Issues"
#     ]
#   }
# }
# {
#   "1774": {
#     "categories": [
#       "Coverage Issues"
#     ]
#   }
# }
# {
#   "1775": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1776": {
#     "categories": [
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1777": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1778": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1779": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1780": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1781": {
#     "categories": [
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1782": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1783": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1784": {
#     "categories": [
#       "Competitor Data Consumption",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1785": {
#     "categories": [
#       "Coverage Issues"
#     ]
#   }
# }
# {
#   "1786": {
#     "categories": [
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1787": {
#     "categories": [
#       "Agent Behavior",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1788": {
#     "categories": [
#       "Suggestions",
#       "Service Information Request"
#     ]
#   }
# }
# {
#   "1789": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1790": {
#     "categories": [
#       "Data Quality Issues (3G, 4G)",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1791": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1792": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1793": {
#     "categories": [
#       "Service Information Request"
#     ]
#   }
# }
# {
#   "1794": {
#     "categories": [
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1795": {
#     "categories": [
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1796": {
#     "categories": [
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1797": {
#     "categories": [
#       "Coverage Issues"
#     ]
#   }
# }
# {
#   "1798": {
#     "categories": [
#       "Suggestions",
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1799": {
#     "categories": [
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1800": {
#     "categories": [
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1801": {
#     "categories": [
#       "Competitor Plan Flexibility (Mobilis and Djezzy)",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1802": {
#     "categories": [
#       "Coverage Issues"
#     ]
#   }
# }
# {
#   "1803": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1804": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1805": {
#     "categories": [
#       "Service Information Request"
#     ]
#   }
# }
# {
#   "1806": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1807": {
#     "categories": [
#       "Coverage Issues"
#     ]
#   }
# }
# {
#   "1808": {
#     "categories": [
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1809": {
#     "categories": [
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1810": {
#     "categories": [
#       "Suggestions",
#       "Overcharging and Stolen Credit Issues"
#     ]
#   }
# }
# {
#   "1811": {
#     "categories": [
#       "Coverage Issues"
#     ]
#   }
# }
# {
#   "1812": {
#     "categories": [
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1813": {
#     "categories": [
#       "Other"
#     ]
#   }
# }
# {
#   "1814": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1815": {
#     "categories": [
#       "Promotions & Discounts",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1816": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1817": {
#     "categories": [
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1818": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1819": {
#     "categories": [
#       "Coverage Issues",
#       "Service Information Request"
#     ]
#   }
# }
# {
#   "1820": {
#     "categories": [
#       "Agent Behavior"
#     ]
#   }
# }
# {
#   "1821": {
#     "categories": [
#       "Coverage Issues"
#     ]
#   }
# }
# {
#   "1822": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1823": {
#     "categories": [
#       "Suggestions",
#       "Service Information Request"
#     ]
#   }
# }
# {
#   "1824": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1825": {
#     "categories": [
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1826": {
#     "categories": [
#       "Data Quality Issues (3G, 4G)",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1827": {
#     "categories": [
#       "Service Information Request"
#     ]
#   }
# }
# {
#   "1828": {
#     "categories": [
#       "Service Information Request"
#     ]
#   }
# }
# {
#   "1829": {
#     "categories": [
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1830": {
#     "categories": [
#       "Coverage Issues",
#       "Data Quality Issues (3G, 4G)"
#     ]
#   }
# }
# {
#   "1831": {
#     "categories": [
#       "Data Quality Issues (3G, 4G)"
#     ]
#   }
# }
# {
#   "1832": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1833": {
#     "categories": [
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1834": {
#     "categories": [
#       "Promotions & Discounts"
#     ]
#   }
# }
# {
#   "1835": {
#     "categories": [
#       "Service Information Request"
#     ]
#   }
# }
# {
#   "1836": {
#     "categories": [
#       "Suggestions",
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1837": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1838": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1839": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1840": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1841": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1842": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1843": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1844": {
#     "categories": [
#       "Suggestions",
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1845": {
#     "categories": [
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1846": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1847": {
#     "categories": [
#       "Suggestions",
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1848": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1849": {
#     "categories": [
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1850": {
#     "categories": [
#       "Competitor Pricing & Value (Mobilis and Djezzy)",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1851": {
#     "categories": [
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1852": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1853": {
#     "categories": [
#       "Loyalty Expression",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1854": {
#     "categories": [
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1855": {
#     "categories": [
#       "Suggestions",
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1856": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1857": {
#     "categories": [
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1858": {
#     "categories": [
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1859": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1860": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1861": {
#     "categories": [
#       "Promotions & Discounts",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1862": {
#     "categories": [
#       "Competitor Data Consumption",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1863": {
#     "categories": [
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1864": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1865": {
#     "categories": [
#       "Promotions & Discounts",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1866": {
#     "categories": [
#       "Promotions & Discounts",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1867": {
#     "categories": [
#       "Promotions & Discounts",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1868": {
#     "categories": [
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1869": {
#     "categories": [
#       "Service Information Request",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1870": {
#     "categories": [
#       "Overcharging and Stolen Credit Issues",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1871": {
#     "categories": [
#       "Promotions & Discounts"
#     ]
#   }
# }
# {
#   "1872": {
#     "categories": [
#       "Sarcasm",
#       "Irrelevant"
#     ]
#   }
# }
# {
#   "1873": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1874": {
#     "categories": [
#       "Service Information Request"
#     ]
#   }
# }
# {
#   "1875": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1876": {
#     "categories": [
#       "Suggestions",
#       "Competitor Pricing & Discounts"
#     ]
#   }
# }
# {
#   "1877": {
#     "categories": [
#       "Suggestions",
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1878": {
#     "categories": [
#       "Suggestions",
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1879": {
#     "categories": [
#       "Coverage Issues",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1880": {
#     "categories": [
#       "Suggestions",
#       "Other"
#     ]
#   }
# }
# {
#   "1881": {
#     "categories": [
#       "Suggestions",
#       "Other"
#     ]
#   }
# }
# {
#   "1882": {
#     "categories": [
#       "Promotions & Discounts",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1883": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1884": {
#     "categories": [
#       "Suggestions",
#       "Service Information Request"
#     ]
#   }
# }
# {
#   "1885": {
#     "categories": [
#       "Overcharging and Stolen Credit Issues"
#     ]
#   }
# }
# {
#   "1886": {
#     "categories": [
#       "Coverage Issues",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1887": {
#     "categories": [
#       "Suggestions",
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1888": {
#     "categories": [
#       "Service Information Request"
#     ]
#   }
# }
# {
#   "1889": {
#     "categories": [
#       "Call Quality Issues",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1890": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1891": {
#     "categories": [
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1892": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1893": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1894": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1895": {
#     "categories": [
#       "Competitor Pricing & Value (Mobilis and Djezzy)",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1896": {
#     "categories": [
#       "Suggestions",
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1897": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1898": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1899": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1900": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1901": {
#     "categories": [
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1902": {
#     "categories": [
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1903": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1904": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1905": {
#     "categories": [
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1906": {
#     "categories": [
#       "Suggestions"
#     ]
#   }
# }
# {
#   "1907": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1908": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1909": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1910": {
#     "categories": [
#       "Suggestions",
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1911": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "1912": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }

# %%
# Sauvegarder en JSON
json_path = "/content/Results/classified_comments.json"
with open(json_path, "w", encoding="utf-8") as f:
    json.dump(results, f, indent=2, ensure_ascii=False)

# %%
import pandas as pd
import json

# Lire le fichier JSON depuis le disque
with open("/content/Results/classified_comments.json", "r", encoding="utf-8") as f:
    classification_dict = json.load(f)

# Liste des catégories
category_list = [
    "Call Quality Issues",
    "Data Quality Issues (3G, 4G)",
    "Coverage Issues",
    "Response Time",
    "Agent Behavior",
    "Overcharging and Stolen Credit Issues",
    "Billing Errors",
    "Subscription & Plan Issues",
    "Hidden Charges",
    "Suggestions",
    "Promotions & Discounts",
    "Competitor Pricing & Value (Mobilis and Djezzy)",
    "Competitor Plan Flexibility (Mobilis and Djezzy)",
    "Competitor Data Consumption (Mobilis and Djezzy)",
    "Loyalty Expression",
    "Service Information Request",
    "Sarcasme",
    "Irrelevant",
    "Other"
]

# Initialiser toutes les colonnes de catégories à 0
for cat in category_list:
    if cat not in comments_df.columns:
        comments_df[cat] = 0

# Remplir en fonction des catégories détectées
for comment_id_str, data in classification_dict.items():
    comment_id = int(comment_id_str)
    categories = data.get("categories", [])
    for category in categories:
        if category in category_list:
            comments_df.loc[comments_df["ID Comment"] == comment_id, category] = 1
            if category in ("Sarcasme", "Irrelevant"):  # Correct 'or' condition
                comments_df.loc[comments_df["ID Comment"] == comment_id, "Other"] = 1
# Drop "Sarcasme" and "Irrelevant" columns after the loop
comments_df = comments_df.drop(columns=["Sarcasme", "Irrelevant"])

# Sauvegarder le nouveau DataFrame
comments_df.to_csv("/content/Results/comments_df_classified.csv", index=False)

# Afficher un aperçu
print(comments_df.head())
