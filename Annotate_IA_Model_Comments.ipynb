# %% [markdown]
# <a href="https://colab.research.google.com/github/OUARAS-khelil-Rafik/AS-Ooredoo_Djezzy_Mobilis-/blob/main/Annotate_IA_Model_Comments.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install emoji pandas
# Out:
# Collecting emoji
#   Downloading emoji-2.14.1-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading emoji-2.14.1-py3-none-any.whl (590 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 590.6/590.6 kB 8.5 MB/s eta 0:00:00
# Installing collected packages: emoji
# Successfully installed emoji-2.14.1

# %%
import pandas as pd
import re
import emoji

# %%
# Charger les fichiers Excel
comments_df = pd.read_excel('/content/Comments.xlsx')

# Afficher DataFrame "Comments"
comments_df
# Out:
#       ID Post        User Name  \
# 0           1  Samir Bekhouche
# 1           1    Yanise Yanise
# 2           1           Jj Kie
# 3           1     Sakou Younes
# 4           1       راني نعاني
# ...       ...              ...
# 4097      183       Ĺã Rõsë Ýb
# 4098      183      نسمات هادئة
# 4099      183   ملك ملهاش غيرك
# 4100      183        سعيدي رضا
# 4101      183    جيبلي فيت فيت
#
#                                                Comments Sentiments
# 0                                                   NaN     Neutre
# 1     سلام عليكم ورحمة لديا مشكلة ! فليكسيت 100 دج و...    Negatif
# 2                                    كل عام و انتم بخير    Positif
# 3                                    كل عام و أنتم بخير    Positif
# 4                                     كل عام و حنا بخير    Positif
# ...                                                 ...        ...
# 4097                                               ❤️❤️    Positif
# 4098                                               💕💕💕💕    Positif
# 4099                                            ❤❤❤❤❤❤🌹    Positif
# 4100                                                NaN     Neutre
# 4101                                           ❤️❤️❤️❤️    Positif
#
# [4102 rows x 4 columns]

# %% [markdown]
# # Pré-traitement

# %%
# Suppression des lignes où "User Name" est "Djezzy", "Mobilis" ou "Ooredoo"
comments_df = comments_df[~comments_df["User Name"].isin(["Djezzy", "Mobilis", "Ooredoo Algérie"])]
comments_df
# Out:
#       ID Post        User Name  \
# 0           1  Samir Bekhouche
# 1           1    Yanise Yanise
# 2           1           Jj Kie
# 3           1     Sakou Younes
# 4           1       راني نعاني
# ...       ...              ...
# 4097      183       Ĺã Rõsë Ýb
# 4098      183      نسمات هادئة
# 4099      183   ملك ملهاش غيرك
# 4100      183        سعيدي رضا
# 4101      183    جيبلي فيت فيت
#
#                                                Comments Sentiments
# 0                                                   NaN     Neutre
# 1     سلام عليكم ورحمة لديا مشكلة ! فليكسيت 100 دج و...    Negatif
# 2                                    كل عام و انتم بخير    Positif
# 3                                    كل عام و أنتم بخير    Positif
# 4                                     كل عام و حنا بخير    Positif
# ...                                                 ...        ...
# 4097                                               ❤️❤️    Positif
# 4098                                               💕💕💕💕    Positif
# 4099                                            ❤❤❤❤❤❤🌹    Positif
# 4100                                                NaN     Neutre
# 4101                                           ❤️❤️❤️❤️    Positif
#
# [4077 rows x 4 columns]

# %%
comments_df = comments_df.dropna(subset=["Comments"])
comments_df = comments_df[comments_df["Comments"].str.strip() != ""]
comments_df
# Out:
#       ID Post       User Name  \
# 1           1   Yanise Yanise
# 2           1          Jj Kie
# 3           1    Sakou Younes
# 4           1      راني نعاني
# 5           1     Wahab Ziadi
# ...       ...             ...
# 4096      183      مر سلين 'ے
# 4097      183      Ĺã Rõsë Ýb
# 4098      183     نسمات هادئة
# 4099      183  ملك ملهاش غيرك
# 4101      183   جيبلي فيت فيت
#
#                                                Comments Sentiments
# 1     سلام عليكم ورحمة لديا مشكلة ! فليكسيت 100 دج و...    Negatif
# 2                                    كل عام و انتم بخير    Positif
# 3                                    كل عام و أنتم بخير    Positif
# 4                                     كل عام و حنا بخير    Positif
# 5                                     كل عام و حنا بخير    Positif
# ...                                                 ...        ...
# 4096                                             🩷🩷🩷🩷🩷🩷    Positif
# 4097                                               ❤️❤️    Positif
# 4098                                               💕💕💕💕    Positif
# 4099                                            ❤❤❤❤❤❤🌹    Positif
# 4101                                           ❤️❤️❤️❤️    Positif
#
# [3897 rows x 4 columns]

# %%
comments_df = comments_df.loc[comments_df["Comments"].shift() != comments_df["Comments"]]
comments_df
# Out:
#       ID Post       User Name  \
# 1           1   Yanise Yanise
# 2           1          Jj Kie
# 3           1    Sakou Younes
# 4           1      راني نعاني
# 6           1      أحمد فيراس
# ...       ...             ...
# 4096      183      مر سلين 'ے
# 4097      183      Ĺã Rõsë Ýb
# 4098      183     نسمات هادئة
# 4099      183  ملك ملهاش غيرك
# 4101      183   جيبلي فيت فيت
#
#                                                Comments Sentiments
# 1     سلام عليكم ورحمة لديا مشكلة ! فليكسيت 100 دج و...    Negatif
# 2                                    كل عام و انتم بخير    Positif
# 3                                    كل عام و أنتم بخير    Positif
# 4                                     كل عام و حنا بخير    Positif
# 6                                                     🥰    Positif
# ...                                                 ...        ...
# 4096                                             🩷🩷🩷🩷🩷🩷    Positif
# 4097                                               ❤️❤️    Positif
# 4098                                               💕💕💕💕    Positif
# 4099                                            ❤❤❤❤❤❤🌹    Positif
# 4101                                           ❤️❤️❤️❤️    Positif
#
# [3798 rows x 4 columns]

# %%
def normalize_arabic(text):
    text = text.lower()
    text = re.sub("گ", "ك", text)
    text = re.sub("ڭ", "ك", text)
    text = re.sub("ڤ", "ق", text)
    text = re.sub("ڨ", "ق", text)
    text = re.sub("پ", "ب", text)
    text = re.sub("é", "e", text)
    text = re.sub("ê", "e", text)
    text = re.sub("ë", "e", text)
    text = re.sub("ç", "c", text)
    text = re.sub("à", "a", text)
    text = re.sub("â", "a", text)
    text = re.sub("ä", "a", text)
    text = re.sub("î", "i", text)
    text = re.sub("ï", "a", text)
    text = re.sub("æ", "ae", text)
    text = re.sub("œ", "oe", text)
    return text

# Appliquer la normalisation
comments_df["Comments"] = comments_df["Comments"].apply(normalize_arabic)

comments_df
# Out:
# <ipython-input-7-378408359fdb>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   comments_df["Comments"] = comments_df["Comments"].apply(normalize_arabic)
#       ID Post       User Name  \
# 1           1   Yanise Yanise
# 2           1          Jj Kie
# 3           1    Sakou Younes
# 4           1      راني نعاني
# 6           1      أحمد فيراس
# ...       ...             ...
# 4096      183      مر سلين 'ے
# 4097      183      Ĺã Rõsë Ýb
# 4098      183     نسمات هادئة
# 4099      183  ملك ملهاش غيرك
# 4101      183   جيبلي فيت فيت
#
#                                                Comments Sentiments
# 1     سلام عليكم ورحمة لديا مشكلة ! فليكسيت 100 دج و...    Negatif
# 2                                    كل عام و انتم بخير    Positif
# 3                                    كل عام و أنتم بخير    Positif
# 4                                     كل عام و حنا بخير    Positif
# 6                                                     🥰    Positif
# ...                                                 ...        ...
# 4096                                             🩷🩷🩷🩷🩷🩷    Positif
# 4097                                               ❤️❤️    Positif
# 4098                                               💕💕💕💕    Positif
# 4099                                            ❤❤❤❤❤❤🌹    Positif
# 4101                                           ❤️❤️❤️❤️    Positif
#
# [3798 rows x 4 columns]

# %%
def clean_text(text):
    text = emoji.replace_emoji(text, replace=" ")  # Supprimer les emojis
    text = re.sub(r'http\S+ | htps\S+', " ", str(text))  # Supprimer les hyperliens
    text = re.sub(r'((www\.[^\s]+)|(https?://[^\s]+))', " ", str(text))  # Supprimer les URL
    text = re.sub(r'@\S+', '', str(text))  # Supprimer les mots commençant par @
    text = text.replace("_", " ").replace("#", "")  # Supprimer # et _
    text = text.replace("'", " ")  # Supprimer '
    text = re.sub(r'\. | , | ، | ؛', " ", text)  # Supprimer les ponctuations

    # Supprimer les mots réservés
    text = re.sub(r'\bRT\b | \bRetweeted\b', " ", text)

    # Supprimer tout caractère spécial sauf l'alphabet arabe et latin
    text = re.sub(r'[^a-zA-Z0-9\u0600-\u06FF\s]', " ", text)

    # Supprimer les voyelles courtes arabes (حركات)
    harakat = "[\u064B-\u0652]"  # Comprend
    text = re.sub(harakat, '', text)

    text = re.sub(r"(.)\1{2,}", r"\1", text)  # Supprimer les caractères consécutifs en double
    text = text.replace('\n', " ").replace('/', " ")  # Supprimer sauts de ligne et /
    text = re.sub(r'[^\w\s]', " ", text)  # Supprimer les caractères spéciaux

    return text.strip()

comments_df["Comments"] = comments_df["Comments"].apply(clean_text)

# Remplacer les valeurs nulles par une chaîne vide
comments_df["Comments"] = comments_df["Comments"].fillna('')

comments_df = comments_df.dropna(subset=["Comments"])
comments_df = comments_df[comments_df["Comments"].str.strip() != ""]

comments_df
# Out:
# <ipython-input-8-6f9557cab524>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   comments_df["Comments"] = comments_df["Comments"].apply(clean_text)
# <ipython-input-8-6f9557cab524>:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   comments_df["Comments"] = comments_df["Comments"].fillna('')
#       ID Post                User Name  \
# 1           1            Yanise Yanise
# 2           1                   Jj Kie
# 3           1             Sakou Younes
# 4           1               راني نعاني
# 7           1  مروان سيدهم سيدهم مروان
# ...       ...                      ...
# 4075      183                    Kà Nø
# 4078      183                  Noé Noé
# 4087      183              Koléa Koléa
# 4093      183              Oussama Zhm
# 4095      183               B-m Lamine
#
#                                                Comments Sentiments
# 1     سلام عليكم ورحمة لديا مشكلة فليكسيت 100 دج و ب...    Negatif
# 2                                    كل عام و انتم بخير    Positif
# 3                                    كل عام و أنتم بخير    Positif
# 4                                     كل عام و حنا بخير    Positif
# 7     كل عام وأنتم بخير وأتمنا رد علا أسإلتي علا لحا...    Positif
# ...                                                 ...        ...
# 4075  ريقلو كونيكسيو غي العاب خسرت شحال من بارطيا عل...    Negatif
# 4078                                         رمضان كريم    Positif
# 4087                                         رمضان كريم    Positif
# 4093  walah cnx ta3koum rahi t3ayi lyamat hadou safi...    Negatif
# 4095  سلام عليكم اوريدو عندي مشكل كل مرة نفليكسي تنح...    Negatif
#
# [3443 rows x 4 columns]

# %%
abbreviations = {
    "mrc": "merci",
    "num": "numéro",
    "numro": "numéro",
    "nn": "non",
    "bn": "bonne",
    "topp": "top",
    "شوي": "قليل",
    "شويا": "قليل",
    "لزونيتي": "رصيد",
    "حنا": "نحن",
    "أسإلتي": "اسئلة",
    "حاص": "خاص",
    "مدام": "بينما",
    "رانا": "نحن",
    "بون": "حسن",
    "توس": "جميع",
    "سبيسيال": "منفرد",
    "سبيال": "منفرد",
    "باه": "لكي",
    "زاف": "كثيرا",
    "بزاف": "كثيرا",
    "نتمني": "نتمنى",
    "فظلكم": "فضلكم",
    "ضلم": "ظلم",
    "ردى": "رد",
    "علاش": "لماذا",
    "علاه": "لماذا",
    "علا": "لماذا",
    "هذ": "هذا",
    "تبرعو": "تبرع",
    "ابليكاسيو": "تطبيق",
    "أبليكاسيون": "تطبيق",
    "أبليكاسيو": "تطبيق",
    "الخاص بكم": "نتاعكم",
    "ديرولنا": "افعلو لنا",
    "ديرو": "افعلو",
    "نحا": "نزع",
    "دير": "افعل",
    "حاجة": "شيء",
    "نتع": "خاص ب",
    "تاع": "خاص ب",
    "تع": "خاص ب",
    "جاوبوني": "رد علي",
    "مشتاركه": "مشاركة",
    "رحو": "اذهبو",
    "هذي": "هذه",
    "يروح": "يذهب",
    "يجي": "يأتي",
    "وقتاه": "متى",
    "وقتاش": "متى",
    "وقتش": "متى",
    "تردولنا": "تردون",
    "نتاع": "خاص ب",
    "شكون": "من",
    "نحيتوها": "نزع",
    "نحيتو": "نزع",
    "نحيت": "نزع",
    "سلفلي": "قرض",
    "سلفولي": "قرض",
    "غدوة": "غدا",
    "تلقى": "تجد",
    "نلقى": "اجد",
    "نأكتيفيها": "تفعيل",
    "نأكتيفي": "تفعيل",
    "ناكتيفي": "تفعيل",
    "نعانيو": "نعانون",
    "نعانو": "نعانون",
    "ميت حال": "رديء",
    "مفهمتش": "لم افهم",
    "انو": "انه",
    "علابالي": "اعلم",
    "ليتو": "اصبحتم",
    "وليتو": "اصبحتم",
    "تدو": "تاخذون",
    "الى": "إلى",
    "خاستني": "احتاج",
    "خستني": "احتاج",
    "مشى": "تعمل",
    "مشا": "تعمل",
    "شكا": "شكوى",
    "شكيت": "شكوى",
    "زرو": "سيء",
    "زيرو": "سيء",
    "سرفيك": "خدمة",
    "سرفيس": "خدمة",
    "جيزي اب": "djezzy app",
    "nchlh": "incha allah",
    "riglou": "regler",
    "bah": "pour",
    "nwaliw": "devenir",
    "مراحش": "لن",
    "مهمش": "ليسو",
    "تعليع": "تعليق",
    "زااف": "كثيرا",
    "khayan": "voleur",
    "djezzyy": "djezzy",
    "ومرديتش": "لم ترد",
    "واش": "ماذا",
    "منبعد": "بعد ذلك",
    "تفتحش": "لا تفتح",
    "ندير": "افعل",
    "راه": "اصبح",
    "لازم": "يجب",
    "pix": "pixx",
    "Twanty": "Twenty",
    "orod": "prod",
    "imtiyaaz": "imtiyaz",
    "tm": "ok",
    "نم": "تم",
    "جداو": "جدا",
    "زلب": "زبل",
    "كونطرا": "عقد",
    "شري": "شراء",
    "توب": "رائع",
    "جزل": "جزيلا",
    "ياسر": "كثيرا",
    "golde": "gold",
    "mknch": "introuvable",
    "rani": "je suis",
    "شكرالكم": "شكرا لكم",
    "viv": "vive",
    "عتل": "ارسل",
    "بعت": "ارسل",
    "لاجونس": "مقر",
    "rpnd": "repond",
    "prv": "prive",
    "svp": "s il vous plais",
    "yennayer": "سنة",
    "amervuh": "سعيدة",
    "assgas": "assegas",
    "asugas": "assegas",
    "asegas": "assegas",
    "amegaz": "amegas",
    "amgaz": "amegas",
    "amegaz": "amegas",
    "amgaz": "amegas",
    "amegaz": "amegas",
    "خخ": "ضحك",
    "هه": "ضحك",
    "سبي": "سبيسيال",
    "شبكهمشكورين": "شبكة مشكورين",
    "يعطيكمصحه": "يعطيكم صحة",
    "نشله": "ان شاء الله",
    "عندوش": "لا يوجد",
    "خفظو": "تخفيض",
    "مليحة": "حسن",
    "مليحه": "حسن",
    "وله": "و الله",
    "مكمات": "مكالمات",
    "وينتا": "متى",
    "تدوها": "تاخذون",
    "felawen": "tous",
    "ya": "il y a",
    "en": "في",
    "panne": "عطل",
    "happy": "سعيدة",
    "koum": "votre",
    "ayi": "faible",
    "new": "جديدة",
    "year": "سنة",
    "years": "سنة",
    "شنو": "ما هو",
    "هدا": "هذا",
    "شالنج": "تحدي",
    "li": "qui",
    "bghi": "aime",
    "ndirlo": "faire",
    "yji": "viens",
    "lah": "pourquoi",
    "raho": "que il",
    "hbs": "arret",
    "بر": "فقط",
    "برك": "فقط",
    "غي": "الا",
    "غير": "الا",
    "الي": "الى",
    "حسنو": "اصلاح",
    "سقمو": "اصلاح",
    "جوند": "legend",
    "يجاند": "legend",
    "ليجند": "legend",
    "علجال": "من أجل",
    "تثقال": "بطء",
    "كون": "ليت",
    "بغى": "اراد",
    "يبغي": "يريد",
    "نبغي": "نريد",
    "تفرج": "مشاهدة",
    "ماتش": "مباراة",
    "رجا": "رجاء",
    "متمشلكش": "لا تعمل",
    "متمسيلكش": "لا تعمل",
    "لايص": "اماكن",
    "بلايص": "اماكن",
    "بلاصة": "اماكن",
    "نسقسي": "اسأل",
    "اذ": "اذا",
    "يمتي": "بلا حدود",
    "اليميتي": "بلا حدود",
    "خسني": "اريد",
    "باطل": "مجانا",
    "قولد": "gold",
    "تعيف": "سيء",
    "نسييو": "محاولة",
    "نلعبو": "لعب",
    "نكونو": "أكون",
    "عب": "لعب",
    "كف": "كيف",
    "اللهيوفقناجميعاقولويارب": "الله يوفقنا جميع اقولو يارب",
    "congratulations": "مبروك",
    "berkaw": "arret",
    "ser": "vole",
    "تردوش": "لا تردون",
    "هضرت": "تكلمت",
    "باش": "لكي",
    "تحلى": "حل",
    "تحلي": "حل",
    "لينا": "لنا",
    "حض": "حظ",
    "wech": "Quoi",
    "ndirou": "faire",
    "bach": "pour",
    "nrebhou": "gagner",
    "elfe": "mille",
    "mabrok": "felicitations",
    "koules": "tous",
    "moucharikones": "participants",
    "el": "les",
    "mabrouk": "مبروك",
    "اطوههالي": "اعطوها لي",
    "شاب": "جميل",
    "يعطيكمالصحة": "يعطيكم الصحة",
    "illa": "lent",
    "woww": "wow",
    "يارب": "يا رب",
    "كلشي": "كل شيء",
    "كنكتي": "تواصل",
    "مانكونيكتيش": "لا أتواصل",
    "يووز": "yooz",
    "يوز": "yooz",
    "وش": "ما هو",
    "وشمن": "اي",
    "ديما": "dima",
    "راه": "انه",
    "معجبتنيش": "سيء",
    "تحبسلي": "توقف",
    "انتاع": "ل",
    "لوس": "plus",
    "شكراوريدو": "شكرا أوريدو",
    "در": "فعل",
    "رهي": "انه",
    "كاين": "يوجد",
    "مباغش": "لا يريد",
    "يمدلي": "يعطيني",
    "يخرجو": "خروج",
    "اكتر": "أكثر",
    "مايمشيش": "لا يعمل",
    "سوايع": "ساعة",
    "محبتش": "لا",
    "جام": "مستحيل",
    "جامي": "مستحيل",
    "تمشلي": "تعمل",
    "ريفي": "خاص",
    "قاع": "كل",
    "منربحش": "لا أربح",
    "منربحوش": "لا أربح",
    "نقارع": "صبر",
    "مفتحتوهاليش": "لا تفتح",
    "ابونمون": "اشتراك",
    "مساج": "رسالة",
    "رجعو": "رد",
    "صحيتو": "شكرا",
    "لاتوجد": "لا توجد",
    "نلقاش": "لا أجد",
    "ما نلقاش": "لا أجد",
    "كريدي": "رصيد",
    "ريبونديولنا": "رد",
    "جد": "جدا",
    "ينحيولي": "نزع",
    "يحذفولي": "نزع",
    "ماسلفت": "لم اقترض",
    "مدايرا": "لم أفعل",
    "راهي": "إنها",
    "فور": "ممتاز",
    "هايل": "ممتاز",
    "مليح": "جيد",
    "شابة": "جميل",
    "ماصلحتليش": "لا تعمل",
    "إستلاف": "قرض",
    "خص": "اريد",
    "هاذ": "هذا",
    "شحال": "كم",
    "تاكتيفيه": "تفعيل",
    "حتان": "كي",
    "كيفاش": "كيف",
    "غلطة": "خطا",
    "ختاريت": "خيار",
    "ديالي": "خاص بي",
    "حاب": "اريد",
    "ويل": "أو",
    "ابعث": "ارسال",
    "goold": "gold",
    "ماتجاوبوش": "عدم رد",
    "مهدى": "هدية",
    "واشهرالجاي": "شهر موالي",
    "نخلصش": "لا أدفع",
    "ابليس": "plus",
    "تأكتيفها": "تفعيل",
    "هيل": "hayla",
    "هاذي": "هذه",
    "وشمن": "ما هي",
    "جزاير": "جزائر",
    "معن": "معنى",
    "فاه": "فيها",
    "فاش": "اي",
    "مكوبي": "مقطوع",
    "مي": "لكن",
    "مايمشيلك": "لا يعمل",
    "نديرلهم": "اعمل لهم",
    "تتمسخرو": "استهزاء",
    "ريبونديو": "رد",
    "plais" : "من فظلكم",
    "كفاه": "كيف",
    "ندموندي": "طلب",
    "دخلتو": "ادخال",
    "العالميه": "عالمية",
    "قات": "بقي",
    "بقات": "بقي",
    "nechlh": "incha allah",
    "jdida": "جديد",
    "كيفما": "كيف",
    "اندير": "افعل",
    "ذيم": "دائما",
    "وين": "أين",
    "راهي": "هي",
    "ماندمت": "ندم",
    "حشو": "خدعة",
    "حشوة": "خدعة",
    "انشاءاللهتكونمننصيبي": "ان شاء الله تكون من نصيبي",
    "نتمنالهم": "اتمنى",
    "راحوش": "لم يذهب",
    "بادن": "باذن",
    "الي": "الذي",
    "تغلقلو": "غلق",
    "نيمروه": "رقم",
    "يسترجعو": "استرجاع",
    "رانيني": "ranini",
    "عقوبة": "عاقبة",
    "قوب": "عاقبة",
    "حطو": "وضع",
    "لينا": "لنا",
    "ستمرار": "مستمر",
    "لابيلكاسيو": "تطبيق",
    "لبليكاسيو": "تطبيق",
    "متمشيش": "لا تعمل",
    "حبستوها": "توقف",
    "حمال": "تحميل",
    "مزان": "ميزان",
    "جيه": "جهة",
    "فلاترددو": "فلا تترددو",
    "خدمهوعروضاطاقم": "خدمة و عروض طاقم",
    "فلعاصمة": "في عاصمة",
    "nztjwice": " ",
    "refvf": " ",
    "b": " ",
    "br": " ",
    "ابار": "يبارك",
    "يحفضكم": "يحفظكم",
    "يلوس": "plus",
    "تاه": "متى",
    "بف": " ",
    "sagmou": "regler",
    "شويش": "switch",
    "بغية": "اريد",
    "dialkom": "vous",
    "sahel": "facile",
    "toop": "top",
    "هنيء": "مبروك",
    "puse": "sim",
    "pui": "puis",
    "nerbah": "gagne",
    "ghir": "sauf",
    "بيان": "جيدا",
    "ماتمشيش": "لا تعمل",
    "نحافضو": "حفاظ",
    "تخلاص": "انتهاء",
    "متعرفش": "لا تعلم",
    "خاصتا": "خاصة",
    "وفى": "و في",
    "ظل": "دائما",
    "مدرتو": "لم تفعلو",
    "لموبليس": "موبيليس",
    "را": "انه",
    "صر": "حدث",
    "rah": "il est",
    "gae": "tous",
    "dok": "maintenant",
    "لابليكاسيون": "تطبيق",
    "كلش": "كل",
    "مشاءالله": "ما شاء الله",
    "حبس": "توقف",
    "زيد": "ايضا",
    "تسرقو": "سرق",
    "تاكتيفي": "تفعيل",
    "زوعاماء": "زعماء",
    "ul": " ",
    "كدب": "كذب",
    "ميقراسيون": "تبديل",
    "شح": "كم",
    "فيهاش": "لا يوجد",
    "نجاوب": "اجيب",
    "راحت": "ذهب",
    "متسواش": "سيء",
    "تعكم": "خاص بكم",
    "حقاهايلة": "ممتاز",
    "صرقولي": "سرق",
    "صرق": "سرق",
    "ويني": "اين",
    "حمدلله": "حمد لله",
    "رحمن": "رحمان",
    "نشال": "شاء الله",
    "ماشاء": "ما شاء",
    "تنحولي": "نزع",
    "خمسلاف": "خمسة ألف",
    "خمسلاف": "خمسة ألف",
    "مفعلتهاش": "لا تفعيل",
    "سرقتولي": "سرق",
    "لكريدي": "رصيد",
    "انترنتوراها": "اين انترنت",
    "تعييف": "سيء",
    "تعيف": "سيء",
    "ضك": "الان",
    "جزى": "جزاك",
    "نشاء": "ان شاء",
    "إنشاءالله": "ان شاء الله",
    "نشالله": "ان شاء الله",
    "شاءالله": "شاء الله"
}

def replace_abbreviations(text):
    words = text.split()
    return ' '.join([abbreviations[word] if word in abbreviations else word for word in words])

comments_df['Comments'] = comments_df['Comments'].apply(replace_abbreviations)

# %%
from collections import defaultdict
import re

# Dictionnaire de regroupement phonétique
phonetic_groups = {
    "تعبئة": ["كنفليكسيو", "نفليكسي", "نفليكسيو", "فليكس", "تفليكسي", "فليكسولنا", "نفلبكسى", "فليكسيت", "كسي", "فليكسي"],
    "connexion": ["conx", "cnx", "ncx", "conexion", "connection"],
    "reseau": ["wrizo", "rizo", "riso", "rysou", "resou", "risou"],
    "اصلحوا": ["ريقلوه", "ريقلو", "صلحو", "ريقولو", "صلحونا", "عدلو", "ريغلونا", "رقليو", "تريغليونا", "لوتصلحولينا", "تريقلونا", "وريقليو"],
    "شبكة": ["ريزو", "اريزو", "الريزو", "ااريزو", "خط", "خطي", "رزو"],
    "ما به": ["واشي", "وشبيه", "شبيه"],
    "لا يوجد": ["ماكاش", "مكانش", "مكاش", "مكااش", "والو", "معنديش", "الو"],
    "أي": ["كش", "كاش"],
    "انترنت": ["كونيكسيون", "كونكسيو", "كونكزيون", "كونيكسيو", "ليدوني", "انترنات", "انترنيت","نترنت", "أنترنات", "الكنكسيو", "الانثرنات", "الانترنت", "أنترنت",  "اترنات", "الكونيكسيوو", "نت", "لكونيكسيو", "كنكسيو", "كونيكسو", "انترن"],
    "جازي": ["جايز", "جاز", "دجيزي", "دجزي", "جيزي", "جايزي"],
    "اسقاس": ["اسوكاس", "اصكاس", "اسيقاس", "اسكاس"],
    "امقاز": ["أموقاز", "امكاز"],
    "رمز": ["كود", "رزم"],
    "بارك": ["بارى", "بيار", "باراك", "يبارك"],
    "شريحة": ["لابيس", "لبيس", "بيس", "لابوس", "لبييس", "ليبيس", "بوس", "سبيسي", "لبووس", "pis"],
    "اوريدو": ["اريدوو", "لأوريد", "ياؤريدوا", "اوريدوا", "واوريدو", "ااوريدو", "اريدو"],
    "ان شاء": ["إنشاء", "نشالله", "انشاء"],
    "ilimite": ["ilm", "ilmt", "ilimiti", "ilim"],
}

# Création d’un mapping inverse (pour accélérer la recherche)
phonetic_mapping = {}
for standard, variations in phonetic_groups.items():
    for variant in variations:
        phonetic_mapping[variant] = standard

# Fonction de remplacement des variantes phonétiques
def replace_phonetic_variants(text):
    words = text.split()
    return ' '.join([phonetic_mapping[word] if word in phonetic_mapping else word for word in words])

comments_df['Comments'] = comments_df['Comments'].apply(replace_phonetic_variants)

# %%
comments_df["Comments"][1]
# Out:
# 'سلام عليكم ورحمة لديا مشكلة تعبئة 100 دج و بدأت تنقص قليل قليل من 100 دج إلى 75دج و بعدها إلى 50 دج و بعدها إلى 25 دج اين ذهبت رصيد تاعي لن أتكلم بها و لم اتصل بها و ليس لي خاصية رنتي اذن اين ذهب مالي و صار نفس الشيء مع أخي ماهذا لابد من استرجاعه'

# %%
# Add ID column to comments_df
comments_df.insert(0, 'ID Comment', range(1, 1 + len(comments_df)))
comments_df
# Out:
#       ID Comment  ID Post                User Name  \
# 1              1        1            Yanise Yanise
# 2              2        1                   Jj Kie
# 3              3        1             Sakou Younes
# 4              4        1               راني نعاني
# 7              5        1  مروان سيدهم سيدهم مروان
# ...          ...      ...                      ...
# 4075        3439      183                    Kà Nø
# 4078        3440      183                  Noé Noé
# 4087        3441      183              Koléa Koléa
# 4093        3442      183              Oussama Zhm
# 4095        3443      183               B-m Lamine
#
#                                                Comments Sentiments
# 1     سلام عليكم ورحمة لديا مشكلة تعبئة 100 دج و بدأ...    Negatif
# 2                                    كل عام و انتم بخير    Positif
# 3                                    كل عام و أنتم بخير    Positif
# 4                                     كل عام و نحن بخير    Positif
# 7     كل عام وأنتم بخير وأتمنا رد لماذا اسئلة لماذا ...    Positif
# ...                                                 ...        ...
# 4075  اصلحوا انترنت الا العاب خسرت كم من بارطيا من أ...    Negatif
# 4078                                         رمضان كريم    Positif
# 4087                                         رمضان كريم    Positif
# 4093  walah connexion ta3koum rahi t3ayi lyamat hado...    Negatif
# 4095  سلام عليكم اوريدو عندي مشكل كل مرة تعبئة نزع خ...    Negatif
#
# [3443 rows x 5 columns]

# %%
import os

# Vérification du format attendu
assert 'ID Comment' in comments_df.columns and 'Comments' in comments_df.columns, "Les colonnes 'ID Comment' et 'Comments' doivent exister."

# Créer le dossier de résultats
os.makedirs('/content/Results', exist_ok=True)

# %%
# Installer la bibliothèque pour exécuter GGUF
# %pip install llama-cpp-python tqdm

from llama_cpp import Llama
# Out:
# Collecting llama-cpp-python
#   Downloading llama_cpp_python-0.3.8.tar.gz (67.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 MB 9.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (4.67.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.11/dist-packages (from llama-cpp-python) (4.13.2)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.11/dist-packages (from llama-cpp-python) (2.0.2)
# Collecting diskcache>=5.6.1 (from llama-cpp-python)
#   Downloading diskcache-5.6.3-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: jinja2>=2.11.3 in /usr/local/lib/python3.11/dist-packages (from llama-cpp-python) (3.1.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2>=2.11.3->llama-cpp-python) (3.0.2)
# Downloading diskcache-5.6.3-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 3.5 MB/s eta 0:00:00
# Building wheels for collected packages: llama-cpp-python
#   Building wheel for llama-cpp-python (pyproject.toml) ... done
#   Created wheel for llama-cpp-python: filename=llama_cpp_python-0.3.8-cp311-cp311-linux_x86_64.whl size=5959614 sha256=81824ac6af3ebb7bc7a6996aa2dd1972cb77ea90c072dc89e337b33a9999b86a
#   Stored in directory: /root/.cache/pip/wheels/c0/03/66/eb3810eafd55d921b2be32896d1f44313996982360663aa80b
# Successfully built llama-cpp-python
# Installing collected packages: diskcache, llama-cpp-python
# Successfully installed diskcache-5.6.3 llama-cpp-python-0.3.8

# %%
# Créer le dossier de modèle
os.makedirs('/content/models', exist_ok=True)

# !wget -O /content/models/DeepSeek-R1-Distill-Qwen-7B-Q6_K.gguf \
"https://huggingface.co/lmstudio-community/DeepSeek-R1-Distill-Qwen-7B-GGUF/resolve/main/DeepSeek-R1-Distill-Qwen-7B-Q6_K.gguf"
# Out:
# --2025-04-18 22:36:41--  https://huggingface.co/lmstudio-community/DeepSeek-R1-Distill-Qwen-7B-GGUF/resolve/main/DeepSeek-R1-Distill-Qwen-7B-Q6_K.gguf
# Resolving huggingface.co (huggingface.co)... 18.172.134.4, 18.172.134.124, 18.172.134.88, ...
# Connecting to huggingface.co (huggingface.co)|18.172.134.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://cdn-lfs-us-1.hf.co/repos/05/84/058408ebba13ec9fd4556e4187361bb25387663d5ec87e73d85e1abca50bb887/b05e9a3c531cf0ff7ba3ab96c78bfdb68a664e50859ac1245d6322873ff21a7b?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27DeepSeek-R1-Distill-Qwen-7B-Q6_K.gguf%3B+filename%3D%22DeepSeek-R1-Distill-Qwen-7B-Q6_K.gguf%22%3B&Expires=1745019402&Policy=&Signature=oLw44hhodmbfPARjte10m2JmlkTbdZoGSuooFpnBi5LvEG5aBAw5W2Yp%7E0DSHFwLHCq45tDRxqO15cfmZdyMC7o7Hal6OsdH1LHT0C3MuMgRcaEPqVdYTI1MsSQ53vi83zMsOm4Mn7dxTl57OdowGTvMfgRxUTR18nTMidSoHu3x0KFriA6uDX-DUfUFD1kxKhNMvbU4YBZnizQZmH8v2O0SoYGCFjtNrv%7EVrZMLj0hTPIAFceACMTHjHPomNbp2uSL63TTbB%7Eer5r-pM0m6nQMlS3iFJsK-gUXweoOKAFdvheRM76kLUduGe6GQKuGu0QZUr9xl-JCOxSKFTnt0lA__&Key-Pair-Id=K24J24Z295AEI9 [following]
# --2025-04-18 22:36:42--  https://cdn-lfs-us-1.hf.co/repos/05/84/058408ebba13ec9fd4556e4187361bb25387663d5ec87e73d85e1abca50bb887/b05e9a3c531cf0ff7ba3ab96c78bfdb68a664e50859ac1245d6322873ff21a7b?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27DeepSeek-R1-Distill-Qwen-7B-Q6_K.gguf%3B+filename%3D%22DeepSeek-R1-Distill-Qwen-7B-Q6_K.gguf%22%3B&Expires=1745019402&Policy=&Signature=oLw44hhodmbfPARjte10m2JmlkTbdZoGSuooFpnBi5LvEG5aBAw5W2Yp%7E0DSHFwLHCq45tDRxqO15cfmZdyMC7o7Hal6OsdH1LHT0C3MuMgRcaEPqVdYTI1MsSQ53vi83zMsOm4Mn7dxTl57OdowGTvMfgRxUTR18nTMidSoHu3x0KFriA6uDX-DUfUFD1kxKhNMvbU4YBZnizQZmH8v2O0SoYGCFjtNrv%7EVrZMLj0hTPIAFceACMTHjHPomNbp2uSL63TTbB%7Eer5r-pM0m6nQMlS3iFJsK-gUXweoOKAFdvheRM76kLUduGe6GQKuGu0QZUr9xl-JCOxSKFTnt0lA__&Key-Pair-Id=K24J24Z295AEI9
# Resolving cdn-lfs-us-1.hf.co (cdn-lfs-us-1.hf.co)... 108.156.120.70, 108.156.120.46, 108.156.120.121, ...
# Connecting to cdn-lfs-us-1.hf.co (cdn-lfs-us-1.hf.co)|108.156.120.70|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6254198464 (5.8G) [binary/octet-stream]
# Saving to: ‘/content/models/DeepSeek-R1-Distill-Qwen-7B-Q6_K.gguf’
#
# /content/models/Dee 100%[===================>]   5.82G   222MB/s    in 36s
#
# 2025-04-18 22:37:18 (164 MB/s) - ‘/content/models/DeepSeek-R1-Distill-Qwen-7B-Q6_K.gguf’ saved [6254198464/6254198464]

# %%
from llama_cpp import Llama

llm = Llama(
    model_path="/content/models/DeepSeek-R1-Distill-Qwen-7B-Q6_K.gguf",
    n_gpu_layers=-1,  # Utilise toutes les couches sur le GPU
    use_mlock=False,
    n_ctx=2048,
    verbose=False
)
# Out:
# llama_init_from_model: n_ctx_per_seq (2048) < n_ctx_train (131072) -- the full capacity of the model will not be utilized

# %%
system_prompt = (
    "You are a highly intelligent multilingual assistant specialized in **telecom customer feedback classification**. "
    "Your job is to analyze each customer comment, identified by its **unique ID**, and classify it into one or more **appropriate subcategories** based on the content.\n\n"

    "### 🎯 Classification Subcategories:\n"
    "- **Call Quality Issues** (e.g., Dropped calls, Voice distortion, Call connection failures, Can't hear the other person)\n"
    "- **Data Quality Issues (3G, 4G)** (e.g., Slow internet or something is slow, No connection, Intermittent connectivity, Mobile data not working properly)\n"
    "- **Coverage Issues** (e.g., Weak signal, Dead zones, No service in certain areas, Network outages in cities or villages)\n"
    "- **Response Time** (e.g., Slow customer support response, Long wait times on hotline or chat, Delayed service resolution)\n"
    "- **Agent Behavior** (e.g., Rude or unhelpful agents, Lack of knowledge, Unprofessional attitude, Didn’t solve my problem)\n"
    "- **Overcharging and Stolen Credit Issues** (e.g., Unexpected charges, Credit deducted without usage, Sudden balance loss after recharge)\n"
    "- **Billing Errors** (e.g., Wrong invoice details, Duplicate charges, Inaccurate amounts shown on bill, Postpaid billing problems)\n"
    "- **Subscription & Plan Issues** (e.g., Forced subscriptions, Plan switched without consent, Unwanted service activation, Difficult to unsubscribe)\n"
    "- **Hidden Charges** (e.g., Unclear pricing, Unexpected fees, Not informed about deductions, Surprise costs after service use)\n"
    "- **Suggestions** (e.g., Add 5G, Improve offers, Lower prices, Requesting better bundles or roaming options)\n"
    "- **Promotions & Discounts** (e.g., Misleading promotions, No actual benefit, Ads say something else, Discounts not applied)\n"
    "- **Competitor Pricing & Value (Mobilis and Djezzy)** (e.g., Better pricing or deals from competitors, More data or minutes for the same price)\n"
    "- **Competitor Plan Flexibility (Mobilis and Djezzy)** (e.g., More customizable plans by competitors, Ability to build own bundles)\n"
    "- **Competitor Data Consumption (Mobilis and Djezzy)** (e.g., Faster data exhaustion compared to competitors, My data lasts longer on Djezzy)\n"
    "- **Loyalty Expression** (e.g., Well done, Good service, Satisfied customer, Happy New Year, Saha Ramdankom, Thank you messages)\n"
    "- **Service Information Request** (e.g., What is the code for loan? How to activate roaming? How to check balance? Questions about using a service or feature)\n"
    "- **Other** (e.g., Irrelevant, incomprehensible, sarcasm, unrelated comment, joke or spam)\n\n"


    "### 🧠 Classification Instructions:\n"
    "1. Carefully read the content of each comment.\n"
    "2. Determine which subcategories best represent the issue(s) or suggestion(s) expressed.\n"
    "3. Multiple subcategories are allowed when relevant and even encouraged when multiple issues are present.\n"
    "4. DO NOT limit to one category if the comment contains multiple concerns.\n"

    "### 📤 Output Format:\n"
    "Respond **strictly** using the following JSON structure (no extra explanations):\n\n"
      "{\n"
      "  \"45\": {\n"
      "    \"categories\": [\"Promotions & Discounts\", \"Suggestions\"]\n"
      "  },\n"
      "  \"69\": {\n"
      "    \"categories\": [\"Call Quality Issues\"]\n"
      "  }\n"
      "}\n\n"

    "⚠️ **Important Notes**:\n"
    "- Do NOT include any commentary or explanation in the output.\n"
    "- Always use the exact category labels listed above.\n"
    "- Do NOT invent new categories.\n"
    "- Ensure output is in **valid JSON format**.\n"
    "- Each comment ID must map to at least one subcategory.\n\n"

    "### 🌐 Supported Languages:\n"
    "- Arabic (العربية)\n"
    "- Algerian Darija (الدارجة الجزائرية)\n"
    "- French (Français)\n"
    "- English\n\n"

    "Proceed with the classification."
)

# %%
# Prendre seulement les 100 premiers commentaires pour le test
test_df = comments_df.head(100).copy()
test_df
# Out:
#      ID Comment  ID Post                  User Name  \
# 1             1        1              Yanise Yanise
# 2             2        1                     Jj Kie
# 3             3        1               Sakou Younes
# 4             4        1                 راني نعاني
# 7             5        1    مروان سيدهم سيدهم مروان
# ..          ...      ...                        ...
# 108          96        4               Принц Князья
# 109          97        4  ياسين ميمز - Yassine mems
# 110          98        4                   عبد الحق
# 111          99        4                   Ämïnë Mø
# 112         100        4                   Ďøģ Māðð
#
#                                               Comments Sentiments
# 1    سلام عليكم ورحمة لديا مشكلة تعبئة 100 دج و بدأ...    Negatif
# 2                                   كل عام و انتم بخير    Positif
# 3                                   كل عام و أنتم بخير    Positif
# 4                                    كل عام و نحن بخير    Positif
# 7    كل عام وأنتم بخير وأتمنا رد لماذا اسئلة لماذا ...    Positif
# ..                                                 ...        ...
# 108  جازي افعلو هدة حسن كي شغل مسابقة ليروح يتفرج ل...    Positif
# 109                           و نتوما مديرولناش مسابقة     Neutre
# 110                 عاشت الجزائر عربية مسلمة إلى الابد    Positif
# 111                              ما به تطبيق محبش يدخل    Negatif
# 112                             تطبيقكم لا يعمل اصلحوه    Negatif
#
# [100 rows x 5 columns]

# %%
# Extraire uniquement les commentaires dont l'ID_Comment est entre 697 et 1000 inclus
test_df = comments_df[(comments_df["ID Comment"] >= 697) & (comments_df["ID Comment"] <= 1000)].copy()

# Aperçu du DataFrame filtré
test_df
# Out:
#       ID Comment  ID Post                                          User Name  \
# 770          697       31                                       Seddike Bahi
# 771          698       31                                            Yac Ine
# 772          699       31                           ChouLii Ricardo Quaresma
# 773          700       31                                             人生 パズル
# 774          701       31                                     Kavani Samaras
# ...          ...      ...                                                ...
# 1137         996       57                                           Rango Dz
# 1138         997       57                                        Kader Samir
# 1139         998       57  جمعية أصدقاء البيئة و التنمية المستدامة الحجار...
# 1140         999       57                                           Med Foot
# 1141        1000       57                                          Oüm Mänær
#
#                                                Comments Sentiments
# 770                          شبكة عيان 60جيكا ذهب مجانا    Negatif
# 771                                   يوجد مشكل فالريزو    Negatif
# 772                               كيف لكي نقدر نكتيفيها     Neutre
# 773                   هل يمكن تحويل من منفرد إلى legend     Neutre
# 774   يا شركة السراقين بارح فليكست 100 اليوم ديتوها ...    Negatif
# ...                                                 ...        ...
# 1137                                             بتوفيق    Positif
# 1138                     بإذن الجزائر خضراء صادقه جارية     Neutre
# 1139             سلام هل نستطيع القيام بحملة تشجير معكم     Neutre
# 1140                                       يعطيكم الصحة    Positif
# 1141                                       يعطيكم الصحة    Positif
#
# [304 rows x 5 columns]

# %%
import json
import re
from tqdm import tqdm
from time import sleep

# Boucle d’inférence
results = {}

for idx, row in test_df.iterrows():
    comment_id = str(row['ID Comment'])
    comment_text = str(row['Comments'])

    prompt = (
        system_prompt
        + f"\n\nClassify the following customer comment. Respond using ONLY the JSON format.\n"
        + f"Comment ID: \"{comment_id}\"\n"
        + f"Comment: \"{comment_text}\"\n"
        + "\nRespond with at least 2 categories if multiple issues.\n"
        + "\nReturn the result in this exact structure:\n"
        + "{\n"
        + f"  \"{comment_id}\": {{\n"
        + "    \"categories\": [\"Category A\", \"Category B\"]\n"
        + "  }\n"
        + "}\n"
        + "\n⚠️ DO NOT COMMENT. DO NOT THINK. ONLY RETURN STRICT JSON."
    )

    try:
        output = llm(prompt, max_tokens=256, temperature=0.0)
        raw_response = output["choices"][0]["text"].strip()

        # Extraction du JSON
        json_match = re.search(r"\{.*\}", raw_response, re.DOTALL)
        if json_match:
            json_str = json_match.group()
            parsed = json.loads(json_str)
            results.update(parsed)
            print(json.dumps(parsed, indent=2, ensure_ascii=False))  # 👈 Affichage formaté JSON uniquement
        else:
            raise ValueError("No JSON found")

    except Exception:
        fallback = {
            comment_id: {
                "categories": ["Other"]
            }
        }
        results.update(fallback)
        print(json.dumps(fallback, indent=2, ensure_ascii=False))

    sleep(0.5)
# Out:
# {
#   "697": {
#     "categories": [
#       "Coverage Issues",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "698": {
#     "categories": [
#       "Coverage Issues",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "699": {
#     "categories": [
#       "Service Information Request",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "700": {
#     "categories": [
#       "Suggestions",
#       "Service Information Request"
#     ]
#   }
# }
# {
#   "701": {
#     "categories": [
#       "Suggestions",
#       "Service Information Request"
#     ]
#   }
# }
# {
#   "702": {
#     "categories": [
#       "Loyalty Expression",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "703": {
#     "categories": [
#       "Coverage Issues",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "704": {
#     "categories": [
#       "Suggestions",
#       "Competitor Pricing & Value (Mobilis and Djezzy)"
#     ]
#   }
# }
# {
#   "705": {
#     "categories": [
#       "Service Information Request",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "706": {
#     "categories": [
#       "Suggestions",
#       "Competitor Pricing & Value (Mobilis and Djezzy)"
#     ]
#   }
# }
# {
#   "707": {
#     "categories": [
#       "Suggestions",
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "708": {
#     "categories": [
#       "Loyalty Expression",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "709": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "710": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "711": {
#     "categories": [
#       "Coverage Issues",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "712": {
#     "categories": [
#       "Suggestions",
#       "Other"
#     ]
#   }
# }
# {
#   "713": {
#     "categories": [
#       "Suggestions",
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "714": {
#     "categories": [
#       "Overcharging and Stolen Credit Issues",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "715": {
#     "categories": [
#       "Suggestions",
#       "Service Information Request"
#     ]
#   }
# }
# {
#   "716": {
#     "categories": [
#       "Promotions & Discounts",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "717": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "718": {
#     "categories": [
#       "Suggestions",
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "719": {
#     "categories": [
#       "Suggestions",
#       "Other"
#     ]
#   }
# }
# {
#   "720": {
#     "categories": [
#       "Competitor Pricing & Value (Mobilis and Djezzy)",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "721": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "722": {
#     "categories": [
#       "Loyalty Expression",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "723": {
#     "categories": [
#       "Suggestions",
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "724": {
#     "categories": [
#       "Data Quality Issues (3G, 4G)",
#       "Coverage Issues"
#     ]
#   }
# }
# {
#   "725": {
#     "categories": [
#       "Coverage Issues"
#     ]
#   }
# }
# {
#   "726": {
#     "categories": [
#       "Coverage Issues",
#       "Call Quality Issues"
#     ]
#   }
# }
# {
#   "727": {
#     "categories": [
#       "Other"
#     ]
#   }
# }
# {
#   "728": {
#     "categories": [
#       "Competitor Pricing & Value (Mobilis and Djezzy)",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "729": {
#     "categories": [
#       "Competitor Pricing & Value (Mobilis and Djezzy)",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "730": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "731": {
#     "categories": [
#       "Coverage Issues",
#       " suggestions"
#     ]
#   }
# }
# {
#   "732": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "733": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "734": {
#     "categories": [
#       "Suggestions",
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "735": {
#     "categories": [
#       "Other"
#     ]
#   }
# }
# {
#   "736": {
#     "categories": [
#       "Coverage Issues",
#       "Billing Errors"
#     ]
#   }
# }
# {
#   "737": {
#     "categories": [
#       "Competitor Pricing & Discounts",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "738": {
#     "categories": [
#       "Coverage Issues",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "739": {
#     "categories": [
#       "Data Quality Issues (3G, 4G)",
#       "Coverage Issues"
#     ]
#   }
# }
# {
#   "740": {
#     "categories": [
#       "Coverage Issues",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "741": {
#     "categories": [
#       "Overcharging and Stolen Credit Issues",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "742": {
#     "categories": [
#       "Competitor Pricing & Value (Mobilis and Djezzy)",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "743": {
#     "categories": [
#       "Subscription & Plan Issues",
#       "Promotions & Discounts"
#     ]
#   }
# }
# {
#   "744": {
#     "categories": [
#       "Call Quality Issues",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "745": {
#     "categories": [
#       "Coverage Issues",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "746": {
#     "categories": [
#       "Suggestions",
#       "Service Information Request"
#     ]
#   }
# }
# {
#   "747": {
#     "categories": [
#       "Coverage Issues",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "748": {
#     "categories": [
#       "Coverage Issues"
#     ]
#   }
# }
# {
#   "749": {
#     "categories": [
#       "Loyalty Expression",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "750": {
#     "categories": [
#       "Suggestions",
#       "Competitor Plan Flexibility (Mobilis and Djezzy)"
#     ]
#   }
# }
# {
#   "751": {
#     "categories": [
#       "Other"
#     ]
#   }
# }
# {
#   "752": {
#     "categories": [
#       "Competitor Pricing & Value (Mobilis and Djezzy)",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "753": {
#     "categories": [
#       "Coverage Issues",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "754": {
#     "categories": [
#       "Coverage Issues"
#     ]
#   }
# }
# {
#   "755": {
#     "categories": [
#       "Promotions & Discounts",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "756": {
#     "categories": [
#       "Coverage Issues",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "757": {
#     "categories": [
#       "Overcharging and Stolen Credit Issues",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "758": {
#     "categories": [
#       "Suggestions",
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "759": {
#     "categories": [
#       "Data Quality Issues (3G, 4G)",
#       "Coverage Issues"
#     ]
#   }
# }
# {
#   "760": {
#     "categories": [
#       "Loyalty Expression",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "761": {
#     "categories": [
#       "Loyalty Expression",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "762": {
#     "categories": [
#       "Suggestions",
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "763": {
#     "categories": [
#       "Suggestions",
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "764": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "765": {
#     "categories": [
#       "Suggestions",
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "766": {
#     "categories": [
#       "Overcharging and Stolen Credit Issues",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "767": {
#     "categories": [
#       "Coverage Issues",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "768": {
#     "categories": [
#       "Coverage Issues",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "769": {
#     "categories": [
#       "Coverage Issues",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "770": {
#     "categories": [
#       "Overcharging and Stolen Credit Issues",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "771": {
#     "categories": [
#       "Promotions & Discounts",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "772": {
#     "categories": [
#       "Suggestions",
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "773": {
#     "categories": [
#       "Coverage Issues"
#     ]
#   }
# }
# {
#   "774": {
#     "categories": [
#       "Coverage Issues",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "775": {
#     "categories": [
#       "Loyalty Expression",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "776": {
#     "categories": [
#       "Competitor Data Consumption",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "777": {
#     "categories": [
#       "Suggestions",
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "778": {
#     "categories": [
#       "Competitor Pricing & Value (Mobilis and Djezzy)",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "779": {
#     "categories": [
#       "Suggestions",
#       "Other"
#     ]
#   }
# }
# {
#   "780": {
#     "categories": [
#       "Competitor Pricing & Value (Mobilis and Djezzy)",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "781": {
#     "categories": [
#       "Suggestions",
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "782": {
#     "categories": [
#       "Suggestions",
#       "Overcharging and Stolen Credit Issues"
#     ]
#   }
# }
# {
#   "783": {
#     "categories": [
#       "Suggestions",
#       "Other"
#     ]
#   }
# }
# {
#   "784": {
#     "categories": [
#       "Service Information Request",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "785": {
#     "categories": [
#       "Service Information Request",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "786": {
#     "categories": [
#       "Competitor Pricing & Value (Mobilis and Djezzy)",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "787": {
#     "categories": [
#       "Suggestions",
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "788": {
#     "categories": [
#       "Suggestions",
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "789": {
#     "categories": [
#       "Other"
#     ]
#   }
# }
# {
#   "790": {
#     "categories": [
#       "Overcharging and Stolen Credit Issues",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "791": {
#     "categories": [
#       "Suggestions",
#       "Other"
#     ]
#   }
# }
# {
#   "792": {
#     "categories": [
#       "Suggestions",
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "793": {
#     "categories": [
#       "Overcharging and Stolen Credit Issues",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "794": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "795": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "796": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "797": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "798": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "799": {
#     "categories": [
#       "Suggestions",
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "800": {
#     "categories": [
#       "Suggestions",
#       "Other"
#     ]
#   }
# }
# {
#   "801": {
#     "categories": [
#       "Other"
#     ]
#   }
# }
# {
#   "802": {
#     "categories": [
#       "Promotions & Discounts",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "803": {
#     "categories": [
#       "Suggestions",
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "804": {
#     "categories": [
#       "Other"
#     ]
#   }
# }
# {
#   "805": {
#     "categories": [
#       "Suggestions",
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "806": {
#     "categories": [
#       "Service Information Request",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "807": {
#     "categories": [
#       "Suggestions",
#       "Other"
#     ]
#   }
# }
# {
#   "808": {
#     "categories": [
#       "Call Quality Issues",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "809": {
#     "categories": [
#       "Competitor Plan Flexibility (Mobilis and Djezzy)",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "810": {
#     "categories": [
#       "Competitor Plan Flexibility (Mobilis and Djezzy)",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "811": {
#     "categories": [
#       "Competitor Pricing & Value (Mobilis and Djezzy)",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "812": {
#     "categories": [
#       "Suggestions",
#       "Other"
#     ]
#   }
# }
# {
#   "813": {
#     "categories": [
#       "Competitor Data Consumption",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "814": {
#     "categories": [
#       "Loyalty Expression",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "815": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "816": {
#     "categories": [
#       "Loyalty Expression",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "817": {
#     "categories": [
#       "Loyalty Expression",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "818": {
#     "categories": [
#       "Suggestions",
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "819": {
#     "categories": [
#       "Loyalty Expression",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "820": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "821": {
#     "categories": [
#       "Loyalty Expression",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "822": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "823": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "824": {
#     "categories": [
#       "Suggestions",
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "825": {
#     "categories": [
#       "Suggestions",
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "826": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "827": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "828": {
#     "categories": [
#       "Loyalty Expression",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "829": {
#     "categories": [
#       "Competitor Data Consumption",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "830": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "831": {
#     "categories": [
#       "Coverage Issues",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "832": {
#     "categories": [
#       "Coverage Issues",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "833": {
#     "categories": [
#       "Coverage Issues",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "834": {
#     "categories": [
#       "Overcharging and Stolen Credit Issues",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "835": {
#     "categories": [
#       "Coverage Issues",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "836": {
#     "categories": [
#       "Data Quality Issues (3G, 4G)",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "837": {
#     "categories": [
#       "Other"
#     ]
#   }
# }
# {
#   "838": {
#     "categories": [
#       "Suggestions",
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "839": {
#     "categories": [
#       "Suggestions",
#       "Overcharging and Stolen Credit Issues"
#     ]
#   }
# }
# {
#   "840": {
#     "categories": [
#       "Subscription & Plan Issues",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "841": {
#     "categories": [
#       "Suggestions",
#       "Overcharging and Stolen Credit Issues"
#     ]
#   }
# }
# {
#   "842": {
#     "categories": [
#       "Data Quality Issues (3G, 4G)",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "843": {
#     "categories": [
#       "Suggestions",
#       "Service Information Request"
#     ]
#   }
# }
# {
#   "844": {
#     "categories": [
#       "Subscription & Plan Issues",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "845": {
#     "categories": [
#       "Coverage Issues",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "846": {
#     "categories": [
#       "Competitor Pricing & Value (Mobilis and Djezzy)",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "847": {
#     "categories": [
#       "Loyalty Expression",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "848": {
#     "categories": [
#       "Loyalty Expression",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "849": {
#     "categories": [
#       "Competitor Data Consumption",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "850": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "851": {
#     "categories": [
#       "Loyalty Expression",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "852": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "853": {
#     "categories": [
#       "Loyalty Expression",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "854": {
#     "categories": [
#       "Suggestions",
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "855": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "856": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "857": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "858": {
#     "categories": [
#       "Other"
#     ]
#   }
# }
# {
#   "859": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "860": {
#     "categories": [
#       "Competitor Data Consumption",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "861": {
#     "categories": [
#       "Suggestions",
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "862": {
#     "categories": [
#       "Suggestions",
#       "Other"
#     ]
#   }
# }
# {
#   "863": {
#     "categories": [
#       "Competitor Pricing & Value (Mobilis and Djezzy)",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "864": {
#     "categories": [
#       "Coverage Issues",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "865": {
#     "categories": [
#       "Data Quality Issues (3G, 4G)",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "866": {
#     "categories": [
#       "Suggestions",
#       "Other"
#     ]
#   }
# }
# {
#   "867": {
#     "categories": [
#       "Coverage Issues",
#       "Promotions & Discounts"
#     ]
#   }
# }
# {
#   "868": {
#     "categories": [
#       "Subscription & Plan Issues",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "869": {
#     "categories": [
#       "Suggestions",
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "870": {
#     "categories": [
#       "Loyalty Expression",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "871": {
#     "categories": [
#       "Overcharging and Stolen Credit Issues",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "872": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "873": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "874": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "875": {
#     "categories": [
#       "Coverage Issues"
#     ]
#   }
# }
# {
#   "876": {
#     "categories": [
#       "Coverage Issues",
#       "Service Information Request"
#     ]
#   }
# }
# {
#   "877": {
#     "categories": [
#       "Other"
#     ]
#   }
# }
# {
#   "878": {
#     "categories": [
#       "Suggestions",
#       "Other"
#     ]
#   }
# }
# {
#   "879": {
#     "categories": [
#       "Subscription & Plan Issues",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "880": {
#     "categories": [
#       "Suggestions"
#     ]
#   }
# }
# {
#   "881": {
#     "categories": [
#       "Coverage Issues",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "882": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "883": {
#     "categories": [
#       "Suggestions",
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "884": {
#     "categories": [
#       "Loyalty Expression",
#       "Service Information Request"
#     ]
#   }
# }
# {
#   "885": {
#     "categories": [
#       "Suggestions",
#       "Service Information Request"
#     ]
#   }
# }
# {
#   "886": {
#     "categories": [
#       "Other",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "887": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "888": {
#     "categories": [
#       "Loyalty Expression",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "889": {
#     "categories": [
#       "Sarcasm",
#       "Irrelevant"
#     ]
#   }
# }
# {
#   "890": {
#     "categories": [
#       "Competitor Pricing & Value (Mobilis and Djezzy)",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "891": {
#     "categories": [
#       "Suggestions",
#       "Overcharging and Stolen Credit Issues"
#     ]
#   }
# }
# {
#   "892": {
#     "categories": [
#       "Promotions & Discounts",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "893": {
#     "categories": [
#       "Overcharging and Stolen Credit Issues",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "894": {
#     "categories": [
#       "Suggestions",
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "895": {
#     "categories": [
#       "Competitor Data Consumption",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "896": {
#     "categories": [
#       "Coverage Issues",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "897": {
#     "categories": [
#       "Suggestions",
#       "Other"
#     ]
#   }
# }
# {
#   "898": {
#     "categories": [
#       "Coverage Issues",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "899": {
#     "categories": [
#       "Suggestions",
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "900": {
#     "categories": [
#       "Coverage Issues",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "901": {
#     "categories": [
#       "Coverage Issues",
#       "Promotions & Discounts"
#     ]
#   }
# }
# {
#   "902": {
#     "categories": [
#       "Coverage Issues"
#     ]
#   }
# }
# {
#   "903": {
#     "categories": [
#       "Subscription & Plan Issues",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "904": {
#     "categories": [
#       "Overcharging and Stolen Credit Issues",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "905": {
#     "categories": [
#       "Coverage Issues"
#     ]
#   }
# }
# {
#   "906": {
#     "categories": [
#       "Loyalty Expression",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "907": {
#     "categories": [
#       "Loyalty Expression",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "908": {
#     "categories": [
#       "Sarcasm",
#       "Irrelevant"
#     ]
#   }
# }
# {
#   "909": {
#     "categories": [
#       "Coverage Issues",
#       "Service Information Request"
#     ]
#   }
# }
# {
#   "910": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "911": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "912": {
#     "categories": [
#       "Data Quality Issues (3G, 4G)",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "913": {
#     "categories": [
#       "Loyalty Expression",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "914": {
#     "categories": [
#       "Suggestions",
#       "Service Information Request"
#     ]
#   }
# }
# {
#   "915": {
#     "categories": [
#       "Suggestions",
#       "Other"
#     ]
#   }
# }
# {
#   "916": {
#     "categories": [
#       "Loyalty Expression",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "917": {
#     "categories": [
#       "Suggestions",
#       "Agent Behavior"
#     ]
#   }
# }
# {
#   "918": {
#     "categories": [
#       "Coverage Issues",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "919": {
#     "categories": [
#       "Suggestions",
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "920": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "921": {
#     "categories": [
#       "Data Quality Issues (3G, 4G)",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "922": {
#     "categories": [
#       "Suggestions",
#       "Overcharging and Stolen Credit Issues"
#     ]
#   }
# }
# {
#   "923": {
#     "categories": [
#       "Coverage Issues",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "924": {
#     "categories": [
#       "Suggestions",
#       "Service Information Request"
#     ]
#   }
# }
# {
#   "925": {
#     "categories": [
#       "Competitor Pricing & Value (Mobilis and Djezzy)",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "926": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "927": {
#     "categories": [
#       "Promotions & Discounts",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "928": {
#     "categories": [
#       "Coverage Issues",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "929": {
#     "categories": [
#       "Other"
#     ]
#   }
# }
# {
#   "930": {
#     "categories": [
#       "Other"
#     ]
#   }
# }
# {
#   "931": {
#     "categories": [
#       "Other"
#     ]
#   }
# }
# {
#   "932": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "933": {
#     "categories": [
#       "Coverage Issues",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "934": {
#     "categories": [
#       "Other"
#     ]
#   }
# }
# {
#   "935": {
#     "categories": [
#       "Suggestions",
#       "Service Information Request"
#     ]
#   }
# }
# {
#   "936": {
#     "categories": [
#       "Coverage Issues",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "937": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "938": {
#     "categories": [
#       "Service Information Request",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "939": {
#     "categories": [
#       "Data Quality Issues (3G, 4G)",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "940": {
#     "categories": [
#       "Coverage Issues",
#       "Sarcasm or Irrelevant"
#     ]
#   }
# }
# {
#   "941": {
#     "categories": [
#       "Coverage Issues",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "942": {
#     "categories": [
#       "Suggestions",
#       "Subscription & Plan Issues"
#     ]
#   }
# }
# {
#   "943": {
#     "categories": [
#       "Overcharging and Stolen Credit Issues",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "944": {
#     "categories": [
#       "Competitor Pricing & Value (Mobilis and Djezzy)",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "945": {
#     "categories": [
#       "Loyalty Expression",
#       "Service Information Request"
#     ]
#   }
# }
# {
#   "946": {
#     "categories": [
#       "Suggestions",
#       "Service Information Request"
#     ]
#   }
# }
# {
#   "947": {
#     "categories": [
#       "Loyalty Expression",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "948": {
#     "categories": [
#       "Suggestions",
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "949": {
#     "categories": [
#       "Suggestions",
#       "Overcharging and Stolen Credit Issues"
#     ]
#   }
# }
# {
#   "950": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "951": {
#     "categories": [
#       "Coverage Issues",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "952": {
#     "categories": [
#       "Competitor Pricing & Value (Mobilis and Djezzy)",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "953": {
#     "categories": [
#       "Loyalty Expression",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "954": {
#     "categories": [
#       "Coverage Issues",
#       "Data Quality Issues (3G, 4G)"
#     ]
#   }
# }
# {
#   "955": {
#     "categories": [
#       "Other"
#     ]
#   }
# }
# {
#   "956": {
#     "categories": [
#       "Suggestions",
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "957": {
#     "categories": [
#       "Data Quality Issues (3G, 4G)",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "958": {
#     "categories": [
#       "Competitor Pricing & Value (Mobilis and Djezzy)",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "959": {
#     "categories": [
#       "Coverage Issues"
#     ]
#   }
# }
# {
#   "960": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "961": {
#     "categories": [
#       "Other"
#     ]
#   }
# }
# {
#   "962": {
#     "categories": [
#       "Loyalty Expression",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "963": {
#     "categories": [
#       "Suggestions",
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "964": {
#     "categories": [
#       "Loyalty Expression",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "965": {
#     "categories": [
#       "Competitor Pricing & Value (Mobilis and Djezzy)",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "966": {
#     "categories": [
#       "Other"
#     ]
#   }
# }
# {
#   "967": {
#     "categories": [
#       "Loyalty Expression",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "968": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "969": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "970": {
#     "categories": [
#       "Suggestions",
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "971": {
#     "categories": [
#       "Environmental Impact",
#       "Social Impact"
#     ]
#   }
# }
# {
#   "972": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "973": {
#     "categories": [
#       "Loyalty Expression",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "974": {
#     "categories": [
#       "Loyalty Expression",
#       "Suggestions"
#     ]
#   }
# }
# {
#   "975": {
#     "categories": [
#       "Loyalty Expression"
#     ]
#   }
# }
# {
#   "976": {
#     "categories": [
#       "Suggestions",
#       "Service Information Request"
#     ]
#   }
# }

# %%
# Sauvegarder en JSON
json_path = "/content/Results/classified_comments.json"
with open(json_path, "w", encoding="utf-8") as f:
    json.dump(results, f, indent=2, ensure_ascii=False)

# %%
import pandas as pd
import json

# Lire le fichier JSON depuis le disque
with open("/content/Results/classified_comments.json", "r", encoding="utf-8") as f:
    classification_dict = json.load(f)

# Liste des catégories
category_list = [
    "Call Quality Issues",
    "Data Quality Issues (3G, 4G)",
    "Coverage Issues",
    "Response Time",
    "Agent Behavior",
    "Overcharging and Stolen Credit Issues",
    "Billing Errors",
    "Subscription & Plan Issues",
    "Hidden Charges",
    "Suggestions",
    "Promotions & Discounts",
    "Competitor Pricing & Value (Mobilis and Djezzy)",
    "Competitor Plan Flexibility (Mobilis and Djezzy)",
    "Competitor Data Consumption (Mobilis and Djezzy)",
    "Loyalty Expression",
    "Service Information Request",
    "Other"
]

# Initialiser toutes les colonnes de catégories à 0
for cat in category_list:
    if cat not in comments_df.columns:
        comments_df[cat] = 0

# Remplir en fonction des catégories détectées
for comment_id_str, data in classification_dict.items():
    comment_id = int(comment_id_str)
    categories = data.get("categories", [])
    for category in categories:
        if category in category_list:
            comments_df.loc[comments_df["ID Comment"] == comment_id, category] = 1

# Sauvegarder le nouveau DataFrame
comments_df.to_csv("/content/Results/comments_df_classified.csv", index=False)

# Afficher un aperçu
print(comments_df.head())
