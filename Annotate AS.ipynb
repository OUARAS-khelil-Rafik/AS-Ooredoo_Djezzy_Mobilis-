# %%
import pandas as pd
import os

# Define the paths to the input files
comments_path = "/kaggle/input/comments-posts-ooredoo-djezzy-mobilis/Comments_clean.csv"
posts_path = "/kaggle/input/comments-posts-ooredoo-djezzy-mobilis/Posts_clean.csv"

# Define the output directory (working directory)
output_dir = "./"

# Ensure the output directory exists
os.makedirs(output_dir, exist_ok=True)

# Read the CSV files
comments_df = pd.read_csv(comments_path)
posts_df = pd.read_csv(posts_path)

# Define the output file paths
comments_csv_path = os.path.join(output_dir, "Comments_clean.csv")
posts_csv_path = os.path.join(output_dir, "Posts_clean.csv")

# Save the DataFrames to CSV
comments_df.to_csv(comments_csv_path, index=False)
posts_df.to_csv(posts_csv_path, index=False)

print(f"Files have been saved to {output_dir}:")
print(f"- {comments_csv_path}")
print(f"- {posts_csv_path}")
# Out:
# Files have been saved to ./:
# - ./Comments_clean.csv
# - ./Posts_clean.csv

# %%
# Chemin de fichier CSV
posts_csv_path = "/kaggle/working/Posts_clean.csv"

# Lire le fichier CSV dans de DataFrame
posts_df = pd.read_csv(posts_csv_path)

# Afficher les premières lignes pour vérifier
print("\nPosts DataFrame:")
posts_df
# Out:
# Posts DataFrame:
#       ID                                           Contents  \
# 0      1          جازي تمنى سنة سعيد djezzy سعيدة جديدة سنة
# 1      2  راك عطل أريد رصيد خدمة tranquilo خاص djezzy سا...
# 2      3                               it time to be legend
# 3      4  djezzy souhaite سنة سعيدة جازي تقدم أحر تهنئة ...
# 4      5                                               قريب
# ..   ...                                                ...
# 178  179  إثارة لعب تتعاش خاص ooredoo تضاعف إنترنت my oo...
# 179  180        ooredoo dima رابح شيء جديد لكي ربح أستناونا
# 180  181  عاش جو رمضاني رائع خلال إفطار ftour دارتو oore...
# 181  182  ضاعف اشتراك إنترنت خاص خلال شهر رمضان my oored...
# 182  183  عاشق سينما عربي حمل تطبيق شاهد استمتع أفضل فيل...
#
#                                              Lien Post  Nb Like  Nb Love  \
# 0    https://www.facebook.com/djezzy/posts/78822751...      272       45
# 1    https://www.facebook.com/watch/?v=106882928102...      255       28
# 2    https://www.facebook.com/djezzy/posts/39256499...      257       51
# 3         https://www.facebook.com/share/p/19UDNBoQ1k/      621      231
# 4        https://www.facebook.com/share/v/12B9LZySBRe/      288       49
# ..                                                 ...      ...      ...
# 178       https://www.facebook.com/share/p/1KGHZQuXex/      208       46
# 179       https://www.facebook.com/share/v/1Bc7FtdDPx/      625      125
# 180      https://www.facebook.com/reel/954679512980806      280       40
# 181  https://www.facebook.com/watch/?v=193245186050...      148       35
# 182  https://www.facebook.com/OoredooDZ/posts/44139...      215       46
#
#      Nb Care  Nb Wow  Nb Sad  Nb Angry  Nb Haha  Company        Date
# 0          0       1       1        76       14   Djezzy  2024-01-01
# 1          0       1       0        12       31   Djezzy  2024-01-04
# 2          2       0       0         2        8   Djezzy  2024-01-10
# 3         10       3       0         1      300   Djezzy  2024-01-11
# 4          4       0       0         3       24   Djezzy  2024-01-12
# ..       ...     ...     ...       ...      ...      ...         ...
# 178        6       0       0         0        1  Ooredoo  2024-03-26
# 179       14       0       1         1        1  Ooredoo  2024-03-27
# 180        7       1       1         0        0  Ooredoo  2024-03-28
# 181        3       0       0         2        0  Ooredoo  2024-03-28
# 182        5       0       0         1        0  Ooredoo  2024-03-30
#
# [183 rows x 12 columns]

# %%
import pandas as pd

# Chemin de fichier CSV
comments_csv_path = "/kaggle/working/Comments_clean.csv"

# Lire les fichiers CSV dans des DataFrames
comments_df = pd.read_csv(comments_csv_path)

# Afficher les premières lignes pour vérifier
print("Comments DataFrame:")
comments_df
# Out:
# Comments DataFrame:
#       ID Post      User Name  \
# 0           1  Yanise Yanise
# 1           1         Jj Kie
# 2           1   Sakou Younes
# 3           1     راني نعاني
# 4           1    Wahab Ziadi
# ...       ...            ...
# 3945      183  Smiley Tipaza
# 3946      183    Koléa Koléa
# 3947      183   Salah Lamine
# 3948      183    Oussama Zhm
# 3949      183     B-m Lamine
#
#                                                Comments
# 0     سلام رحمة لدى مشكلة تعبئة بدأ نقص قليل قليل  ا...
# 1                                               عام خير
# 2                                               عام خير
# 3                                               عام خير
# 4                                               عام خير
# ...                                                 ...
# 3945                                         رمضان كريم
# 3946                                         رمضان كريم
# 3947          غلق رقم مقر قدر استرجاع رد علي رب يجازيكم
# 3948  walah connexion rahi faible lyamat hadou safi ...
# 3949                  سلام أوريدو مشكل مرة تعبئة نزع حل
#
# [3950 rows x 3 columns]

# %%
posts_df["Contents"]
# Out:
# 0              جازي تمنى سنة سعيد djezzy سعيدة جديدة سنة
# 1      راك عطل أريد رصيد خدمة tranquilo خاص djezzy سا...
# 2                                   it time to be legend
# 3      djezzy souhaite سنة سعيدة جازي تقدم أحر تهنئة ...
# 4                                                   قريب
#                              ...
# 178    إثارة لعب تتعاش خاص ooredoo تضاعف إنترنت my oo...
# 179          ooredoo dima رابح شيء جديد لكي ربح أستناونا
# 180    عاش جو رمضاني رائع خلال إفطار ftour دارتو oore...
# 181    ضاعف اشتراك إنترنت خاص خلال شهر رمضان my oored...
# 182    عاشق سينما عربي حمل تطبيق شاهد استمتع أفضل فيل...
# Name: Contents, Length: 183, dtype: object

# %%
comments_df["Comments"]
# Out:
# 0       سلام رحمة لدى مشكلة تعبئة بدأ نقص قليل قليل  ا...
# 1                                                 عام خير
# 2                                                 عام خير
# 3                                                 عام خير
# 4                                                 عام خير
#                               ...
# 3945                                           رمضان كريم
# 3946                                           رمضان كريم
# 3947            غلق رقم مقر قدر استرجاع رد علي رب يجازيكم
# 3948    walah connexion rahi faible lyamat hadou safi ...
# 3949                    سلام أوريدو مشكل مرة تعبئة نزع حل
# Name: Comments, Length: 3950, dtype: object
